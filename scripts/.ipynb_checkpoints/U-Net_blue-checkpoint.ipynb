# %% [markdown]
# ### Training of modified U-Net for Optic Disc on DRISHTI-GS database (cross-validation fold #0).
#
# 512 px cropped by Optic Disc area and resized to 128 px images were used.
#
# You can either train your model or upload a pre-trained one from:
# *../models_weights/02.03,13:57,OD Cup, U-Net light on DRISHTI-GS 512 px cropped to OD 128 px fold 0, SGD, log_dice loss/last_checkpoint.hdf5*

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
from datetime import datetime
import scipy as sp
import scipy.ndimage
import numpy as np
import pandas as pd
import tensorflow as tf
import skimage
import skimage.exposure
import skimage.transform
from sklearn.model_selection import KFold
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import h5py
from tqdm import tqdm_notebook
from IPython.display import display
from model import *
import cv2

# %%
print('Keras version:', keras.__version__)
print('TensorFlow version:', tf.__version__)
# Out:
# Keras version: 2.3.1
# TensorFlow version: 1.14.0

# %%
K.set_image_data_format('channels_first')

# %%
h5f = h5py.File(os.path.join(os.path.dirname(os.getcwd()), 'data', 'hdf5_datasets', 'DRISHTI_GS.hdf5'), 'r')

# %%
model = get_unet_light(img_rows=128, img_cols=128)
model.compile(optimizer=SGD(lr=1e-4, momentum=0.95),
              loss=log_dice_loss,
              metrics=[mean_IOU_gpu, dice_metric])
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3172: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# C:\Users\Rosana\Documents\Mestrado\dissertacao\unet\scripts\model.py:110: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input=inputs, output=conv10)

# %% [markdown]
# #### DRISHTI-GS
#
# Accessing data, preparing train/validation sets division:

# %%
# Loading full images of desired resolution:
img_train = h5f['DRISHTI-GS/512 px/images']
cup_train = h5f['DRISHTI-GS/512 px/cup']
disc_train = h5f['DRISHTI-GS/512 px/disc']
disc_locations = h5f['DRISHTI-GS/512 px/disc_locations']

# %%
plt.imshow(img_train[45])
plt.show()
print(img_train.shape)
# Out:
# (50, 512, 512, 3)

# %%
img_train, cup_train, disc_train, disc_locations
# Out:
# (<HDF5 dataset "images": shape (50, 512, 512, 3), type "|u1">,
#  <HDF5 dataset "cup": shape (50, 512, 512, 1), type "|u1">,
#  <HDF5 dataset "disc": shape (50, 512, 512, 1), type "|u1">,
#  <HDF5 dataset "disc_locations": shape (50, 4), type "<i8">)

# %%
blue_channel_train = []
for i in (img_train):
    blue = np.zeros(i.shape)
    blue[:,:,2] = i[:,:,2]
    blue_channel_train.append(blue)

# %% [markdown]
# #### Generator of augmented data:

# %%
gen = data_generator(blue_channel_train, cup_train, disc_locations, 128, 'train', batch_size=1)
batch = next(gen)

# %%
plt.imshow(batch[0][0][0])
plt.show()
plt.imshow(batch[1][0][0], cmap=plt.cm.Greys_r); plt.colorbar(); plt.show()

# %%
arch_name = "OD Cup, U-Net light on DRISHTI-GS 512 px cropped to OD 128 px fold 0, SGD, log_dice loss"
weights_folder = os.path.join(os.path.dirname(os.getcwd()), 'models_weights',
                              '{}'.format(arch_name))

# %%
def folder(folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    return folder_name

# %%
img_test = h5f['DRISHTI-GS-test/512 px/images']
cup_test = h5f['DRISHTI-GS-test/512 px/cup']
disc_test = h5f['DRISHTI-GS-test/512 px/disc']
disc_locations_test = h5f['DRISHTI-GS-test/512 px/disc_locations']

# %%
blue_channel_test = []
for i in (img_test):
    blue = np.zeros(i.shape)
    blue[:,:,0] = i[:,:,2]
    blue_channel_test.append(blue)

# %%
X_valid, Y_valid = next(data_generator(blue_channel_test, cup_test, disc_locations_test, train_or_test='test', batch_size=100, stationary=True))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\util\dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))

# %% [markdown]
# ### Training
#
# If a pretrained model needs to be used, first run "Loading model" section below and then go the "Comprehensive visual check", skipping this section.

# %%
history = model.fit_generator(data_generator(blue_channel_train, cup_train, disc_locations, train_or_test='train', batch_size=1), 
                              steps_per_epoch=99,
                              max_queue_size=1,                              
                              validation_data=(X_valid, Y_valid),                              
                              epochs=500, verbose=1,                              
                              callbacks=[CSVLogger(os.path.join(folder(weights_folder), 'training_log_cup_blue.csv')),
                                         ModelCheckpoint(os.path.join(folder(weights_folder),
                                               'last_checkpoint_cup_blue.hdf5'),
                                               monitor='val_loss', mode='min', save_best_only=True, 
                                               save_weights_only=False, verbose=0)])
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\util\dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# Epoch 1/500
# 99/99 [==============================] - 530s 5s/step - loss: 0.8294 - mean_IOU_gpu: 0.1816 - dice_metric: 0.3021 - val_loss: 0.7925 - val_mean_IOU_gpu: 0.2319 - val_dice_metric: 0.3720
# Epoch 2/500
# 99/99 [==============================] - 514s 5s/step - loss: 0.7970 - mean_IOU_gpu: 0.2469 - dice_metric: 0.3880 - val_loss: 0.7746 - val_mean_IOU_gpu: 0.2307 - val_dice_metric: 0.3705
# Epoch 3/500
# 99/99 [==============================] - 502s 5s/step - loss: 0.7969 - mean_IOU_gpu: 0.2429 - dice_metric: 0.3814 - val_loss: 0.7494 - val_mean_IOU_gpu: 0.2431 - val_dice_metric: 0.3862
# Epoch 4/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.7486 - mean_IOU_gpu: 0.2520 - dice_metric: 0.3934 - val_loss: 0.7201 - val_mean_IOU_gpu: 0.2738 - val_dice_metric: 0.4226
# Epoch 5/500
# 99/99 [==============================] - 492s 5s/step - loss: 0.7729 - mean_IOU_gpu: 0.2453 - dice_metric: 0.3838 - val_loss: 0.6943 - val_mean_IOU_gpu: 0.3909 - val_dice_metric: 0.5476
# Epoch 6/500
# 99/99 [==============================] - 492s 5s/step - loss: 0.7314 - mean_IOU_gpu: 0.2713 - dice_metric: 0.4151 - val_loss: 0.6677 - val_mean_IOU_gpu: 0.5145 - val_dice_metric: 0.6640
# Epoch 7/500
# 99/99 [==============================] - 489s 5s/step - loss: 0.6753 - mean_IOU_gpu: 0.3150 - dice_metric: 0.4650 - val_loss: 0.6460 - val_mean_IOU_gpu: 0.6423 - val_dice_metric: 0.7715
# Epoch 8/500
# 99/99 [==============================] - 497s 5s/step - loss: 0.6604 - mean_IOU_gpu: 0.3570 - dice_metric: 0.5075 - val_loss: 0.6794 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 9/500
# 99/99 [==============================] - 490s 5s/step - loss: 0.6042 - mean_IOU_gpu: 0.4212 - dice_metric: 0.5695 - val_loss: 0.8100 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 10/500
# 99/99 [==============================] - 497s 5s/step - loss: 0.5253 - mean_IOU_gpu: 0.4964 - dice_metric: 0.6401 - val_loss: 0.9114 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 11/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.4395 - mean_IOU_gpu: 0.5583 - dice_metric: 0.6934 - val_loss: 1.0336 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 12/500
# 99/99 [==============================] - 496s 5s/step - loss: 0.3575 - mean_IOU_gpu: 0.6044 - dice_metric: 0.7310 - val_loss: 1.2170 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 13/500
# 99/99 [==============================] - 490s 5s/step - loss: 0.3073 - mean_IOU_gpu: 0.6121 - dice_metric: 0.7396 - val_loss: 1.4450 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 14/500
# 99/99 [==============================] - 490s 5s/step - loss: 0.2726 - mean_IOU_gpu: 0.6235 - dice_metric: 0.7500 - val_loss: 1.6907 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 15/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2644 - mean_IOU_gpu: 0.6238 - dice_metric: 0.7487 - val_loss: 1.8935 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 16/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2601 - mean_IOU_gpu: 0.6205 - dice_metric: 0.7448 - val_loss: 2.0688 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 17/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2366 - mean_IOU_gpu: 0.6411 - dice_metric: 0.7632 - val_loss: 2.2345 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 18/500
# 99/99 [==============================] - 488s 5s/step - loss: 0.2518 - mean_IOU_gpu: 0.6250 - dice_metric: 0.7498 - val_loss: 2.3467 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 19/500
# 99/99 [==============================] - 496s 5s/step - loss: 0.2278 - mean_IOU_gpu: 0.6500 - dice_metric: 0.7687 - val_loss: 2.4600 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 20/500
# 99/99 [==============================] - 492s 5s/step - loss: 0.2318 - mean_IOU_gpu: 0.6466 - dice_metric: 0.7658 - val_loss: 2.5518 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 21/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2128 - mean_IOU_gpu: 0.6631 - dice_metric: 0.7806 - val_loss: 2.6194 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 22/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2515 - mean_IOU_gpu: 0.6237 - dice_metric: 0.7477 - val_loss: 2.6807 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 23/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2450 - mean_IOU_gpu: 0.6291 - dice_metric: 0.7525 - val_loss: 2.7515 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 24/500
# 99/99 [==============================] - 495s 5s/step - loss: 0.2188 - mean_IOU_gpu: 0.6567 - dice_metric: 0.7747 - val_loss: 2.8130 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 25/500
# 99/99 [==============================] - 497s 5s/step - loss: 0.2384 - mean_IOU_gpu: 0.6405 - dice_metric: 0.7607 - val_loss: 2.8516 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 26/500
# 99/99 [==============================] - 497s 5s/step - loss: 0.2147 - mean_IOU_gpu: 0.6577 - dice_metric: 0.7770 - val_loss: 2.8930 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 27/500
# 99/99 [==============================] - 494s 5s/step - loss: 0.2131 - mean_IOU_gpu: 0.6578 - dice_metric: 0.7777 - val_loss: 2.9245 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 28/500
# 99/99 [==============================] - 497s 5s/step - loss: 0.2422 - mean_IOU_gpu: 0.6321 - dice_metric: 0.7553 - val_loss: 2.9561 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 29/500
# 99/99 [==============================] - 494s 5s/step - loss: 0.2200 - mean_IOU_gpu: 0.6493 - dice_metric: 0.7707 - val_loss: 2.9754 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 30/500
# 99/99 [==============================] - 498s 5s/step - loss: 0.2157 - mean_IOU_gpu: 0.6579 - dice_metric: 0.7764 - val_loss: 3.0036 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 31/500
# 99/99 [==============================] - 491s 5s/step - loss: 0.2230 - mean_IOU_gpu: 0.6523 - dice_metric: 0.7713 - val_loss: 3.0188 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 32/500
# 99/99 [==============================] - 495s 5s/step - loss: 0.1982 - mean_IOU_gpu: 0.6747 - dice_metric: 0.7909 - val_loss: 3.0539 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 33/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2089 - mean_IOU_gpu: 0.6616 - dice_metric: 0.7806 - val_loss: 3.0789 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 34/500
# 99/99 [==============================] - 494s 5s/step - loss: 0.2164 - mean_IOU_gpu: 0.6549 - dice_metric: 0.7748 - val_loss: 3.0916 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 35/500
# 99/99 [==============================] - 491s 5s/step - loss: 0.2370 - mean_IOU_gpu: 0.6367 - dice_metric: 0.7593 - val_loss: 3.0834 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 36/500
# 99/99 [==============================] - 495s 5s/step - loss: 0.2005 - mean_IOU_gpu: 0.6731 - dice_metric: 0.7892 - val_loss: 3.0822 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 37/500
# 99/99 [==============================] - 497s 5s/step - loss: 0.2015 - mean_IOU_gpu: 0.6700 - dice_metric: 0.7870 - val_loss: 3.0947 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 38/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2093 - mean_IOU_gpu: 0.6669 - dice_metric: 0.7817 - val_loss: 3.1141 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 39/500
# 99/99 [==============================] - 490s 5s/step - loss: 0.2086 - mean_IOU_gpu: 0.6604 - dice_metric: 0.7799 - val_loss: 3.1266 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 40/500
# 99/99 [==============================] - 507s 5s/step - loss: 0.2017 - mean_IOU_gpu: 0.6690 - dice_metric: 0.7869 - val_loss: 3.1358 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 41/500
# 99/99 [==============================] - 494s 5s/step - loss: 0.2035 - mean_IOU_gpu: 0.6669 - dice_metric: 0.7850 - val_loss: 3.1229 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 42/500
# 99/99 [==============================] - 496s 5s/step - loss: 0.1960 - mean_IOU_gpu: 0.6746 - dice_metric: 0.7913 - val_loss: 3.1248 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 43/500
# 99/99 [==============================] - 495s 5s/step - loss: 0.2079 - mean_IOU_gpu: 0.6647 - dice_metric: 0.7822 - val_loss: 3.1641 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 44/500
# 99/99 [==============================] - 496s 5s/step - loss: 0.2045 - mean_IOU_gpu: 0.6624 - dice_metric: 0.7827 - val_loss: 3.1382 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 45/500
# 99/99 [==============================] - 504s 5s/step - loss: 0.1873 - mean_IOU_gpu: 0.6798 - dice_metric: 0.7971 - val_loss: 3.1359 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 46/500
# 99/99 [==============================] - 492s 5s/step - loss: 0.2117 - mean_IOU_gpu: 0.6564 - dice_metric: 0.7775 - val_loss: 3.1282 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 47/500
# 99/99 [==============================] - 495s 5s/step - loss: 0.1996 - mean_IOU_gpu: 0.6697 - dice_metric: 0.7879 - val_loss: 3.1254 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 48/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.1785 - mean_IOU_gpu: 0.6940 - dice_metric: 0.8065 - val_loss: 3.1515 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 49/500
# 99/99 [==============================] - 496s 5s/step - loss: 0.1970 - mean_IOU_gpu: 0.6738 - dice_metric: 0.7898 - val_loss: 3.1468 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 50/500
# 99/99 [==============================] - 506s 5s/step - loss: 0.2039 - mean_IOU_gpu: 0.6654 - dice_metric: 0.7842 - val_loss: 3.2015 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 51/500
# 99/99 [==============================] - 494s 5s/step - loss: 0.1999 - mean_IOU_gpu: 0.6690 - dice_metric: 0.7867 - val_loss: 3.1484 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 52/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.1952 - mean_IOU_gpu: 0.6704 - dice_metric: 0.7894 - val_loss: 3.1549 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 53/500
# 99/99 [==============================] - 495s 5s/step - loss: 0.1839 - mean_IOU_gpu: 0.6831 - dice_metric: 0.7993 - val_loss: 3.2017 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 54/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.2019 - mean_IOU_gpu: 0.6665 - dice_metric: 0.7845 - val_loss: 3.2268 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 55/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.1898 - mean_IOU_gpu: 0.6823 - dice_metric: 0.7962 - val_loss: 3.1771 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 56/500
# 99/99 [==============================] - 490s 5s/step - loss: 0.2042 - mean_IOU_gpu: 0.6600 - dice_metric: 0.7811 - val_loss: 3.1457 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 57/500
# 99/99 [==============================] - 495s 5s/step - loss: 0.1908 - mean_IOU_gpu: 0.6776 - dice_metric: 0.7940 - val_loss: 3.1727 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 58/500
# 99/99 [==============================] - 494s 5s/step - loss: 0.1875 - mean_IOU_gpu: 0.6785 - dice_metric: 0.7957 - val_loss: 3.1433 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 59/500
# 99/99 [==============================] - 493s 5s/step - loss: 0.1880 - mean_IOU_gpu: 0.6766 - dice_metric: 0.7944 - val_loss: 3.1636 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 60/500
# 99/99 [==============================] - 491s 5s/step - loss: 0.1895 - mean_IOU_gpu: 0.6762 - dice_metric: 0.7936 - val_loss: 3.2029 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 61/500
# 99/99 [==============================] - 492s 5s/step - loss: 0.1801 - mean_IOU_gpu: 0.6870 - dice_metric: 0.8023 - val_loss: 3.1567 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 62/500
# 99/99 [==============================] - 490s 5s/step - loss: 0.1643 - mean_IOU_gpu: 0.7108 - dice_metric: 0.8186 - val_loss: 3.2159 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 63/500
# 99/99 [==============================] - 506s 5s/step - loss: 0.1795 - mean_IOU_gpu: 0.6858 - dice_metric: 0.8021 - val_loss: 3.2159 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 64/500
# 99/99 [==============================] - 619s 6s/step - loss: 0.1895 - mean_IOU_gpu: 0.6804 - dice_metric: 0.7950 - val_loss: 3.1809 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 65/500
# 99/99 [==============================] - 610s 6s/step - loss: 0.2031 - mean_IOU_gpu: 0.6586 - dice_metric: 0.7809 - val_loss: 2.9921 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 66/500
# 99/99 [==============================] - 613s 6s/step - loss: 0.1802 - mean_IOU_gpu: 0.6894 - dice_metric: 0.8029 - val_loss: 3.1850 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 67/500
# 99/99 [==============================] - 610s 6s/step - loss: 0.1711 - mean_IOU_gpu: 0.6985 - dice_metric: 0.8103 - val_loss: 3.1236 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 68/500
# 99/99 [==============================] - 1748s 18s/step - loss: 0.1824 - mean_IOU_gpu: 0.6812 - dice_metric: 0.7988 - val_loss: 3.1478 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 69/500
# 99/99 [==============================] - 582s 6s/step - loss: 0.1791 - mean_IOU_gpu: 0.6844 - dice_metric: 0.8015 - val_loss: 3.1840 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 70/500
# 99/99 [==============================] - 538s 5s/step - loss: 0.1785 - mean_IOU_gpu: 0.6925 - dice_metric: 0.8048 - val_loss: 2.9454 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 71/500
# 99/99 [==============================] - 3041s 31s/step - loss: 0.1740 - mean_IOU_gpu: 0.6923 - dice_metric: 0.8070 - val_loss: 3.1912 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 72/500
# 99/99 [==============================] - 571s 6s/step - loss: 0.1762 - mean_IOU_gpu: 0.6869 - dice_metric: 0.8032 - val_loss: 3.0571 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 73/500
# 99/99 [==============================] - 617s 6s/step - loss: 0.1779 - mean_IOU_gpu: 0.6888 - dice_metric: 0.8034 - val_loss: 3.1014 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 74/500
# 99/99 [==============================] - 590s 6s/step - loss: 0.1848 - mean_IOU_gpu: 0.6806 - dice_metric: 0.7970 - val_loss: 2.9771 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 75/500
# 99/99 [==============================] - 529s 5s/step - loss: 0.1790 - mean_IOU_gpu: 0.6872 - dice_metric: 0.8021 - val_loss: 2.8274 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 76/500
# 99/99 [==============================] - 560s 6s/step - loss: 0.1864 - mean_IOU_gpu: 0.6770 - dice_metric: 0.7950 - val_loss: 2.9526 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 77/500
# 99/99 [==============================] - 622s 6s/step - loss: 0.1867 - mean_IOU_gpu: 0.6757 - dice_metric: 0.7937 - val_loss: 2.8393 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 78/500
# 99/99 [==============================] - 623s 6s/step - loss: 0.1756 - mean_IOU_gpu: 0.6892 - dice_metric: 0.8045 - val_loss: 2.7411 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 79/500
# 99/99 [==============================] - 590s 6s/step - loss: 0.1732 - mean_IOU_gpu: 0.6915 - dice_metric: 0.8063 - val_loss: 2.8886 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 80/500
# 99/99 [==============================] - 583s 6s/step - loss: 0.1816 - mean_IOU_gpu: 0.6811 - dice_metric: 0.7982 - val_loss: 2.8062 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 81/500
# 99/99 [==============================] - 584s 6s/step - loss: 0.1773 - mean_IOU_gpu: 0.6899 - dice_metric: 0.8038 - val_loss: 2.7883 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 82/500
# 99/99 [==============================] - 582s 6s/step - loss: 0.1819 - mean_IOU_gpu: 0.6800 - dice_metric: 0.7975 - val_loss: 2.9141 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 83/500
# 99/99 [==============================] - 521s 5s/step - loss: 0.1812 - mean_IOU_gpu: 0.6807 - dice_metric: 0.7986 - val_loss: 2.9930 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 84/500
# 26/99 [======>.......................] - ETA: 10:48 - loss: 0.1744 - mean_IOU_gpu: 0.7036 - dice_metric: 0.8106

# %% [markdown]
# ### Visual check

# %%
pred_iou, pred_dice = [], []
pred_cup = []

for i, img_no in enumerate(test_idx):
    print('image #{}'.format(img_no))
    img = blue_channel_test[img_no]
    batch_X = X_valid[i:i + 1]
    batch_y = Y_valid[i:i + 1]
    
    pred = (model.predict(batch_X)[0, 0] > 0.5).astype(np.float64)
    pred_cup.append(pred)
    corr = th_to_tf_encoding(batch_y)[0, ..., 0]
    
    fig = plt.figure(figsize=(9, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(pred, cmap=plt.cm.Greys_r)
    ax.set_title('Predicted')
    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(corr, cmap=plt.cm.Greys_r)
    ax.set_title('Correct')
    ax = fig.add_subplot(1, 3, 3)
    #ax.imshow(img)
    ax.imshow(th_to_tf_encoding(batch_X)[0])
    ax.set_title('Image')
    plt.show()
    
    cur_iou = K.eval(mean_IOU_gpu(pred[None, None, ...], corr[None, None, ...]))
    cur_dice = K.eval(dice(pred[None, None, ...], corr[None, None, ...]))
    print('IOU: {}\nDice: {}'.format(cur_iou, cur_dice))
    pred_iou.append(cur_iou)
    pred_dice.append(cur_dice)

# %% [markdown]
# Acquiring scores for the validation set:

# %%
print(np.mean(pred_iou))
print(np.mean(pred_dice))

# %% [markdown]
# ### Training and Test disc

# %%
X_valid, Z_valid = next(data_generator(blue_channel_test, disc_test, disc_locations_test, train_or_test='test', batch_size=100, stationary=True))

# %%
history = model.fit_generator(data_generator(blue_channel_train, disc_train, disc_locations, train_or_test='train', batch_size=1), 
                              steps_per_epoch=99,
                              max_queue_size=1,                    
                              validation_data=(X_valid, Z_valid),                              
                              epochs=500, verbose=1,                              
                              callbacks=[CSVLogger(os.path.join(folder(weights_folder), 'training_log_disc_blue.csv')),
                                         ModelCheckpoint(os.path.join(folder(weights_folder),
                                               'last_checkpoint_disc_blue.hdf5'),
                                               monitor='val_loss', mode='min', save_best_only=True, 
                                               save_weights_only=False, verbose=0)])

# %%
pred_iou, pred_dice = [], []
pred_disc = []

for i, img_no in enumerate(test_idx):
    print('image #{}'.format(img_no))
    img = blue_channel_test[img_no]
    batch_X = X_valid[i:i + 1]
    batch_z = Z_valid[i:i + 1]
    
    pred = (model.predict(batch_X)[0, 0] > 0.5).astype(np.float64)
    pred_disc.append(pred)
    corr = th_to_tf_encoding(batch_z)[0, ..., 0]
        
    fig = plt.figure(figsize=(9, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(pred, cmap=plt.cm.Greys_r)
    ax.set_title('Predicted')
    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(corr, cmap=plt.cm.Greys_r)
    ax.set_title('Correct')
    ax = fig.add_subplot(1, 3, 3)
    ax.imshow(th_to_tf_encoding(batch_X)[0])
    ax.set_title('Image')
    plt.show()
    
    cur_iou = K.eval(mean_IOU_gpu(pred[None, None, ...], corr[None, None, ...]))
    cur_dice = K.eval(dice(pred[None, None, ...], corr[None, None, ...]))
    print('IOU: {}\nDice: {}'.format(cur_iou, cur_dice))
    pred_iou.append(cur_iou)
    pred_dice.append(cur_dice)

# %%
print(np.mean(pred_iou))
print(np.mean(pred_dice))

# %%
def ellipseFitting(img):
    contours, hierarchy = cv2.findContours(img.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
    ellipse = np.zeros(img.shape)
    diametro = []
    for ind, cont in enumerate(contours):
        (x,y),(MA,ma),angle = cv2.fitEllipse(cont)
        diametro.append((MA, ma))
        cv2.ellipse(ellipse,(int(x),int(y)),(int(MA/2), int(ma/2)),angle,0,360,(255,255,255),0)
    return ellipse, diametro

# %%
cdrs = []
for i, img_no in enumerate(test_idx):
    cup = pred_cup[i]
    disc = pred_disc[i]
        
    c = cv2.Canny(cup.astype(np.uint8), 1,1)
    d = cv2.Canny(disc.astype(np.uint8), 1,1)
    
    el_c, diam_c = ellipseFitting(c)
    el_d, diam_d = ellipseFitting(d)
        
    if len(diam_d) > 0 and len(diam_c) > 0:
        cdrs.append(diam_c[0][1]/diam_d[0][1])
cdrs
