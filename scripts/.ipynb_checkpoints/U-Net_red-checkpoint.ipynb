# %% [markdown]
# ### Training of modified U-Net for Optic Disc on DRISHTI-GS database (cross-validation fold #0).
#
# 512 px cropped by Optic Disc area and resized to 128 px images were used.
#
# You can either train your model or upload a pre-trained one from:
# *../models_weights/02.03,13:57,OD Cup, U-Net light on DRISHTI-GS 512 px cropped to OD 128 px fold 0, SGD, log_dice loss/last_checkpoint.hdf5*

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import glob
from datetime import datetime
#import warnings
#warnings.simplefilter('ignore')
import scipy as sp
import scipy.ndimage
import numpy as np
import pandas as pd
import tensorflow as tf
import skimage
import skimage.exposure
import skimage.transform
#import mahotas as mh
from sklearn.model_selection import KFold
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline
import h5py
from tqdm import tqdm_notebook
from IPython.display import display
from model import *
import cv2

# %%
print('Keras version:', keras.__version__)
print('TensorFlow version:', tf.__version__)
# Out:
# Keras version: 2.3.1
# TensorFlow version: 1.14.0

# %%
K.set_image_data_format('channels_first')

# %%
h5f = h5py.File(os.path.join(os.path.dirname(os.getcwd()), 'data', 'hdf5_datasets', 'DRISHTI_GS.hdf5'), 'r')

# %%
model = get_unet_light(img_rows=128, img_cols=128)
model.compile(optimizer=SGD(lr=1e-4, momentum=0.95),
              loss=log_dice_loss,
              metrics=[mean_IOU_gpu, dice_metric])
# Out:
# C:\Users\Rosana\Documents\Mestrado\dissertacao\unet\scripts\model.py:108: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input=inputs, output=conv10)

# %% [markdown]
# #### DRISHTI-GS
#
# Accessing data, preparing train/validation sets division:

# %%
# Loading full images of desired resolution:
img_train = h5f['DRISHTI-GS/512 px/images']
cup_train = h5f['DRISHTI-GS/512 px/cup']
disc_train = h5f['DRISHTI-GS/512 px/disc']
disc_locations = h5f['DRISHTI-GS/512 px/disc_locations']

# %%
plt.imshow(img_train[45])
plt.show()
print(img_train.shape)
# Out:
# (50, 512, 512, 3)

# %%
img_train, cup_train, disc_train, disc_locations
# Out:
# (<HDF5 dataset "images": shape (50, 512, 512, 3), type "|u1">,
#  <HDF5 dataset "cup": shape (50, 512, 512, 1), type "|u1">,
#  <HDF5 dataset "disc": shape (50, 512, 512, 1), type "|u1">,
#  <HDF5 dataset "disc_locations": shape (50, 4), type "<i8">)

# %%
red_channel_train = []
for i in (img_train):
    red = np.zeros(i.shape)
    red[:,:,0] = i[:,:,0]
    red_channel_train.append(red)

# %% [markdown]
# #### Generator of augmented data:

# %% [markdown]
# Testing the data generator and generator for augmented data:

# %%
gen = data_generator(red_channel_train, cup_train, disc_locations, 128, 'train', batch_size=1)
batch = next(gen)

# %%
plt.imshow(batch[0][0][0])
plt.show()
plt.imshow(batch[1][0][0], cmap=plt.cm.Greys_r); plt.colorbar(); plt.show()

# %%
arch_name = "OD Cup, U-Net light on DRISHTI-GS 512 px cropped to OD 128 px fold 0, SGD, log_dice loss"
weights_folder = os.path.join(os.path.dirname(os.getcwd()), 'models_weights',
                              '{}'.format(arch_name))

# %%
def folder(folder_name):
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)
    return folder_name

# %%
img_test = h5f['DRISHTI-GS-test/512 px/images']
cup_test = h5f['DRISHTI-GS-test/512 px/cup']
disc_test = h5f['DRISHTI-GS-test/512 px/disc']
disc_locations_test = h5f['DRISHTI-GS-test/512 px/disc_locations']

# %%
red_channel_test = []
for i in (img_test):
    red = np.zeros(i.shape)
    red[:,:,0] = i[:,:,0]
    red_channel_test.append(red)

# %%
X_valid, Y_valid = next(data_generator(red_channel_test, cup_test, disc_locations_test, train_or_test='test', batch_size=100, stationary=True))

# %% [markdown]
# ### Training
#
# If a pretrained model needs to be used, first run "Loading model" section below and then go the "Comprehensive visual check", skipping this section.

# %%
history = model.fit_generator(data_generator(red_channel, cup_train, disc_locations, train_or_test='train', batch_size=1), 
                              steps_per_epoch=99,
                              max_queue_size=1,                              
                              validation_data=(X_valid, Y_valid),
                              epochs=500, verbose=1,                              
                              callbacks=[CSVLogger(os.path.join(folder(weights_folder), 'training_log_cup_red.csv')),
                                         ModelCheckpoint(os.path.join(folder(weights_folder),
                                               'last_checkpoint_cup_red.hdf5'),
                                               monitor='val_loss', mode='min', save_best_only=True, 
                                               save_weights_only=False, verbose=0)])
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\util\dtype.py:135: UserWarning: Possible precision loss when converting from float64 to uint16
#   .format(dtypeobj_in, dtypeobj_out))
# Epoch 1/500
# 99/99 [==============================] - 54s 546ms/step - loss: 1.8707 - mean_IOU_gpu: 0.0595 - dice_metric: 0.1106 - val_loss: 1.8821 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 2/500
# 99/99 [==============================] - 52s 526ms/step - loss: 1.8811 - mean_IOU_gpu: 0.0056 - dice_metric: 0.0110 - val_loss: 1.8043 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 3/500
# 99/99 [==============================] - 58s 587ms/step - loss: 1.7600 - mean_IOU_gpu: 1.6043e-04 - dice_metric: 3.2031e-04 - val_loss: 1.7078 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 4/500
# 99/99 [==============================] - 54s 541ms/step - loss: 1.7273 - mean_IOU_gpu: 1.2849e-04 - dice_metric: 2.5656e-04 - val_loss: 1.5741 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 5/500
# 99/99 [==============================] - 55s 551ms/step - loss: 1.4963 - mean_IOU_gpu: 0.0309 - dice_metric: 0.0572 - val_loss: 1.3059 - val_mean_IOU_gpu: 0.0456 - val_dice_metric: 0.0841
# Epoch 6/500
# 99/99 [==============================] - 61s 616ms/step - loss: 1.2368 - mean_IOU_gpu: 0.1847 - dice_metric: 0.2970 - val_loss: 1.0156 - val_mean_IOU_gpu: 0.1022 - val_dice_metric: 0.1789
# Epoch 7/500
# 99/99 [==============================] - 61s 620ms/step - loss: 1.0076 - mean_IOU_gpu: 0.2907 - dice_metric: 0.4218 - val_loss: 0.7416 - val_mean_IOU_gpu: 0.2538 - val_dice_metric: 0.3910
# Epoch 8/500
# 99/99 [==============================] - 60s 601ms/step - loss: 0.7479 - mean_IOU_gpu: 0.3569 - dice_metric: 0.4986 - val_loss: 0.7437 - val_mean_IOU_gpu: 0.2531 - val_dice_metric: 0.3895
# Epoch 9/500
# 99/99 [==============================] - 60s 604ms/step - loss: 0.9238 - mean_IOU_gpu: 0.3279 - dice_metric: 0.4549 - val_loss: 0.6289 - val_mean_IOU_gpu: 0.3354 - val_dice_metric: 0.4828
# Epoch 10/500
# 99/99 [==============================] - 59s 592ms/step - loss: 0.8091 - mean_IOU_gpu: 0.3632 - dice_metric: 0.4916 - val_loss: 0.4910 - val_mean_IOU_gpu: 0.4256 - val_dice_metric: 0.5779
# Epoch 11/500
# 99/99 [==============================] - 61s 617ms/step - loss: 0.8030 - mean_IOU_gpu: 0.3430 - dice_metric: 0.4736 - val_loss: 1.0056 - val_mean_IOU_gpu: 0.1589 - val_dice_metric: 0.2612
# Epoch 12/500
# 99/99 [==============================] - 61s 618ms/step - loss: 0.7897 - mean_IOU_gpu: 0.3512 - dice_metric: 0.4828 - val_loss: 1.1140 - val_mean_IOU_gpu: 0.1220 - val_dice_metric: 0.2067
# Epoch 13/500
# 99/99 [==============================] - 60s 607ms/step - loss: 0.8443 - mean_IOU_gpu: 0.3626 - dice_metric: 0.4905 - val_loss: 0.5863 - val_mean_IOU_gpu: 0.3532 - val_dice_metric: 0.5025
# Epoch 14/500
# 99/99 [==============================] - 61s 616ms/step - loss: 0.6597 - mean_IOU_gpu: 0.4035 - dice_metric: 0.5381 - val_loss: 0.4217 - val_mean_IOU_gpu: 0.4623 - val_dice_metric: 0.6138
# Epoch 15/500
# 99/99 [==============================] - 59s 600ms/step - loss: 0.7035 - mean_IOU_gpu: 0.3991 - dice_metric: 0.5327 - val_loss: 0.4767 - val_mean_IOU_gpu: 0.4233 - val_dice_metric: 0.5739
# Epoch 16/500
# 99/99 [==============================] - 60s 608ms/step - loss: 0.5620 - mean_IOU_gpu: 0.4350 - dice_metric: 0.5756 - val_loss: 1.5618 - val_mean_IOU_gpu: 0.0172 - val_dice_metric: 0.0318
# Epoch 17/500
# 99/99 [==============================] - 63s 635ms/step - loss: 0.6272 - mean_IOU_gpu: 0.4634 - dice_metric: 0.5937 - val_loss: 0.4024 - val_mean_IOU_gpu: 0.4580 - val_dice_metric: 0.6125
# Epoch 18/500
# 99/99 [==============================] - 40s 403ms/step - loss: 0.6011 - mean_IOU_gpu: 0.4643 - dice_metric: 0.5951 - val_loss: 2.1787 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 19/500
# 99/99 [==============================] - 38s 384ms/step - loss: 0.5875 - mean_IOU_gpu: 0.4722 - dice_metric: 0.6060 - val_loss: 0.2412 - val_mean_IOU_gpu: 0.6580 - val_dice_metric: 0.7859
# Epoch 20/500
# 99/99 [==============================] - 41s 415ms/step - loss: 0.5867 - mean_IOU_gpu: 0.4638 - dice_metric: 0.5950 - val_loss: 2.5103 - val_mean_IOU_gpu: 0.0000e+00 - val_dice_metric: 0.0000e+00
# Epoch 21/500
# 99/99 [==============================] - 41s 412ms/step - loss: 0.4410 - mean_IOU_gpu: 0.5386 - dice_metric: 0.6697 - val_loss: 2.1137 - val_mean_IOU_gpu: 0.0108 - val_dice_metric: 0.0200
# Epoch 22/500
# 99/99 [==============================] - 41s 413ms/step - loss: 0.5227 - mean_IOU_gpu: 0.4965 - dice_metric: 0.6251 - val_loss: 1.1391 - val_mean_IOU_gpu: 0.0854 - val_dice_metric: 0.1314
# Epoch 23/500
# 99/99 [==============================] - 41s 411ms/step - loss: 0.4399 - mean_IOU_gpu: 0.5221 - dice_metric: 0.6569 - val_loss: 1.9138 - val_mean_IOU_gpu: 0.0443 - val_dice_metric: 0.0723
# Epoch 24/500
# 99/99 [==============================] - 41s 414ms/step - loss: 0.4785 - mean_IOU_gpu: 0.5108 - dice_metric: 0.6396 - val_loss: 0.2178 - val_mean_IOU_gpu: 0.6555 - val_dice_metric: 0.7807
# Epoch 25/500
# 99/99 [==============================] - 41s 413ms/step - loss: 0.3606 - mean_IOU_gpu: 0.5614 - dice_metric: 0.6950 - val_loss: 0.7917 - val_mean_IOU_gpu: 0.2658 - val_dice_metric: 0.3760
# Epoch 26/500
# 99/99 [==============================] - 43s 435ms/step - loss: 0.3534 - mean_IOU_gpu: 0.5823 - dice_metric: 0.7093 - val_loss: 0.4468 - val_mean_IOU_gpu: 0.4317 - val_dice_metric: 0.5583
# Epoch 27/500
# 99/99 [==============================] - 39s 393ms/step - loss: 0.3938 - mean_IOU_gpu: 0.5450 - dice_metric: 0.6814 - val_loss: 1.0791 - val_mean_IOU_gpu: 0.1806 - val_dice_metric: 0.2643
# Epoch 28/500
# 99/99 [==============================] - 36s 361ms/step - loss: 0.3683 - mean_IOU_gpu: 0.5799 - dice_metric: 0.7083 - val_loss: 1.4699 - val_mean_IOU_gpu: 0.0987 - val_dice_metric: 0.1511
# Epoch 29/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.4156 - mean_IOU_gpu: 0.5314 - dice_metric: 0.6626 - val_loss: 0.6512 - val_mean_IOU_gpu: 0.3095 - val_dice_metric: 0.4292
# Epoch 30/500
# 99/99 [==============================] - 33s 332ms/step - loss: 0.3400 - mean_IOU_gpu: 0.5916 - dice_metric: 0.7168 - val_loss: 0.7826 - val_mean_IOU_gpu: 0.2497 - val_dice_metric: 0.3548
# Epoch 31/500
# 99/99 [==============================] - 33s 330ms/step - loss: 0.4161 - mean_IOU_gpu: 0.5312 - dice_metric: 0.6628 - val_loss: 0.9366 - val_mean_IOU_gpu: 0.1653 - val_dice_metric: 0.2438
# Epoch 32/500
# 99/99 [==============================] - 33s 332ms/step - loss: 0.3313 - mean_IOU_gpu: 0.5742 - dice_metric: 0.7060 - val_loss: 0.2574 - val_mean_IOU_gpu: 0.6211 - val_dice_metric: 0.7483
# Epoch 33/500
# 99/99 [==============================] - 33s 329ms/step - loss: 0.4118 - mean_IOU_gpu: 0.5446 - dice_metric: 0.6780 - val_loss: 0.6179 - val_mean_IOU_gpu: 0.2909 - val_dice_metric: 0.4165
# Epoch 34/500
# 99/99 [==============================] - 33s 331ms/step - loss: 0.2792 - mean_IOU_gpu: 0.6085 - dice_metric: 0.7405 - val_loss: 0.2456 - val_mean_IOU_gpu: 0.6046 - val_dice_metric: 0.7488
# Epoch 35/500
# 99/99 [==============================] - 33s 331ms/step - loss: 0.2764 - mean_IOU_gpu: 0.6197 - dice_metric: 0.7493 - val_loss: 0.5530 - val_mean_IOU_gpu: 0.3451 - val_dice_metric: 0.4707
# Epoch 36/500
# 99/99 [==============================] - 33s 330ms/step - loss: 0.2746 - mean_IOU_gpu: 0.6144 - dice_metric: 0.7426 - val_loss: 0.1984 - val_mean_IOU_gpu: 0.6625 - val_dice_metric: 0.7910
# Epoch 37/500
# 99/99 [==============================] - 33s 329ms/step - loss: 0.3333 - mean_IOU_gpu: 0.5869 - dice_metric: 0.7157 - val_loss: 0.3570 - val_mean_IOU_gpu: 0.4687 - val_dice_metric: 0.6179
# Epoch 38/500
# 99/99 [==============================] - 33s 334ms/step - loss: 0.3398 - mean_IOU_gpu: 0.5481 - dice_metric: 0.6838 - val_loss: 0.2479 - val_mean_IOU_gpu: 0.5934 - val_dice_metric: 0.7374
# Epoch 39/500
# 99/99 [==============================] - 33s 331ms/step - loss: 0.2547 - mean_IOU_gpu: 0.6236 - dice_metric: 0.7522 - val_loss: 0.3073 - val_mean_IOU_gpu: 0.5284 - val_dice_metric: 0.6786
# Epoch 40/500
# 99/99 [==============================] - 33s 329ms/step - loss: 0.2717 - mean_IOU_gpu: 0.5914 - dice_metric: 0.7267 - val_loss: 0.2014 - val_mean_IOU_gpu: 0.6607 - val_dice_metric: 0.7894
# Epoch 41/500
# 99/99 [==============================] - 33s 329ms/step - loss: 0.2775 - mean_IOU_gpu: 0.6077 - dice_metric: 0.7358 - val_loss: 0.6005 - val_mean_IOU_gpu: 0.3776 - val_dice_metric: 0.4897
# Epoch 42/500
# 99/99 [==============================] - 33s 332ms/step - loss: 0.2842 - mean_IOU_gpu: 0.6031 - dice_metric: 0.7326 - val_loss: 0.2290 - val_mean_IOU_gpu: 0.6172 - val_dice_metric: 0.7550
# Epoch 43/500
# 99/99 [==============================] - 33s 329ms/step - loss: 0.2373 - mean_IOU_gpu: 0.6325 - dice_metric: 0.7626 - val_loss: 0.3177 - val_mean_IOU_gpu: 0.5281 - val_dice_metric: 0.6768
# Epoch 44/500
# 99/99 [==============================] - 33s 333ms/step - loss: 0.2571 - mean_IOU_gpu: 0.6151 - dice_metric: 0.7451 - val_loss: 0.4881 - val_mean_IOU_gpu: 0.4263 - val_dice_metric: 0.5550
# Epoch 45/500
# 99/99 [==============================] - 32s 328ms/step - loss: 0.3023 - mean_IOU_gpu: 0.5776 - dice_metric: 0.7141 - val_loss: 0.1879 - val_mean_IOU_gpu: 0.6817 - val_dice_metric: 0.8007
# Epoch 46/500
# 99/99 [==============================] - 33s 331ms/step - loss: 0.2389 - mean_IOU_gpu: 0.6348 - dice_metric: 0.7618 - val_loss: 0.2158 - val_mean_IOU_gpu: 0.6248 - val_dice_metric: 0.7622
# Epoch 47/500
# 99/99 [==============================] - 33s 329ms/step - loss: 0.2921 - mean_IOU_gpu: 0.5895 - dice_metric: 0.7196 - val_loss: 0.8093 - val_mean_IOU_gpu: 0.3446 - val_dice_metric: 0.4466
# Epoch 48/500
# 99/99 [==============================] - 33s 331ms/step - loss: 0.2215 - mean_IOU_gpu: 0.6507 - dice_metric: 0.7761 - val_loss: 0.1953 - val_mean_IOU_gpu: 0.6604 - val_dice_metric: 0.7895
# Epoch 49/500
# 99/99 [==============================] - 32s 327ms/step - loss: 0.3230 - mean_IOU_gpu: 0.5788 - dice_metric: 0.7130 - val_loss: 0.2182 - val_mean_IOU_gpu: 0.6469 - val_dice_metric: 0.7591
# Epoch 50/500
# 99/99 [==============================] - 33s 332ms/step - loss: 0.3453 - mean_IOU_gpu: 0.5973 - dice_metric: 0.7164 - val_loss: 0.1953 - val_mean_IOU_gpu: 0.6596 - val_dice_metric: 0.7907
# Epoch 51/500
# 99/99 [==============================] - 32s 326ms/step - loss: 0.3189 - mean_IOU_gpu: 0.5787 - dice_metric: 0.7094 - val_loss: 0.2807 - val_mean_IOU_gpu: 0.5467 - val_dice_metric: 0.6957
# Epoch 52/500
# 99/99 [==============================] - 32s 327ms/step - loss: 0.2665 - mean_IOU_gpu: 0.6220 - dice_metric: 0.7475 - val_loss: 0.2170 - val_mean_IOU_gpu: 0.6266 - val_dice_metric: 0.7620
# Epoch 53/500
# 99/99 [==============================] - 33s 331ms/step - loss: 0.2123 - mean_IOU_gpu: 0.6568 - dice_metric: 0.7817 - val_loss: 0.2287 - val_mean_IOU_gpu: 0.6182 - val_dice_metric: 0.7576
# Epoch 54/500
# 99/99 [==============================] - 32s 326ms/step - loss: 0.1784 - mean_IOU_gpu: 0.6847 - dice_metric: 0.8060 - val_loss: 0.2342 - val_mean_IOU_gpu: 0.6083 - val_dice_metric: 0.7498
# Epoch 55/500
# 99/99 [==============================] - 32s 327ms/step - loss: 0.2880 - mean_IOU_gpu: 0.6222 - dice_metric: 0.7461 - val_loss: 0.4021 - val_mean_IOU_gpu: 0.4798 - val_dice_metric: 0.6151
# Epoch 56/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.2284 - mean_IOU_gpu: 0.6417 - dice_metric: 0.7676 - val_loss: 0.2287 - val_mean_IOU_gpu: 0.6029 - val_dice_metric: 0.7463
# Epoch 57/500
# 99/99 [==============================] - 32s 327ms/step - loss: 0.2523 - mean_IOU_gpu: 0.6271 - dice_metric: 0.7545 - val_loss: 0.1944 - val_mean_IOU_gpu: 0.6728 - val_dice_metric: 0.7927
# Epoch 58/500
# 99/99 [==============================] - 33s 330ms/step - loss: 0.1917 - mean_IOU_gpu: 0.6793 - dice_metric: 0.7996 - val_loss: 0.1706 - val_mean_IOU_gpu: 0.6818 - val_dice_metric: 0.8064
# Epoch 59/500
# 99/99 [==============================] - 37s 371ms/step - loss: 0.2467 - mean_IOU_gpu: 0.6277 - dice_metric: 0.7538 - val_loss: 0.2205 - val_mean_IOU_gpu: 0.6158 - val_dice_metric: 0.7569
# Epoch 60/500
# 99/99 [==============================] - 37s 374ms/step - loss: 0.2224 - mean_IOU_gpu: 0.6506 - dice_metric: 0.7728 - val_loss: 0.1543 - val_mean_IOU_gpu: 0.7180 - val_dice_metric: 0.8297
# Epoch 61/500
# 99/99 [==============================] - 36s 365ms/step - loss: 0.2467 - mean_IOU_gpu: 0.6254 - dice_metric: 0.7504 - val_loss: 0.1652 - val_mean_IOU_gpu: 0.7215 - val_dice_metric: 0.8316
# Epoch 62/500
# 99/99 [==============================] - 36s 362ms/step - loss: 0.2018 - mean_IOU_gpu: 0.6688 - dice_metric: 0.7897 - val_loss: 0.2074 - val_mean_IOU_gpu: 0.6355 - val_dice_metric: 0.7744
# Epoch 63/500
# 99/99 [==============================] - 37s 371ms/step - loss: 0.2079 - mean_IOU_gpu: 0.6612 - dice_metric: 0.7853 - val_loss: 0.1907 - val_mean_IOU_gpu: 0.6502 - val_dice_metric: 0.7848
# Epoch 64/500
# 99/99 [==============================] - 37s 373ms/step - loss: 0.2479 - mean_IOU_gpu: 0.6352 - dice_metric: 0.7646 - val_loss: 0.1733 - val_mean_IOU_gpu: 0.6855 - val_dice_metric: 0.8063
# Epoch 65/500
# 99/99 [==============================] - 37s 373ms/step - loss: 0.2471 - mean_IOU_gpu: 0.6342 - dice_metric: 0.7624 - val_loss: 0.1673 - val_mean_IOU_gpu: 0.6979 - val_dice_metric: 0.8138
# Epoch 66/500
# 99/99 [==============================] - 37s 372ms/step - loss: 0.1914 - mean_IOU_gpu: 0.6813 - dice_metric: 0.7996 - val_loss: 0.3438 - val_mean_IOU_gpu: 0.5126 - val_dice_metric: 0.6557
# Epoch 67/500
# 99/99 [==============================] - 37s 373ms/step - loss: 0.2373 - mean_IOU_gpu: 0.6424 - dice_metric: 0.7659 - val_loss: 0.2324 - val_mean_IOU_gpu: 0.5973 - val_dice_metric: 0.7415
# Epoch 68/500
# 99/99 [==============================] - 38s 380ms/step - loss: 0.2420 - mean_IOU_gpu: 0.6310 - dice_metric: 0.7550 - val_loss: 0.1672 - val_mean_IOU_gpu: 0.7042 - val_dice_metric: 0.8175
# Epoch 69/500
# 99/99 [==============================] - 46s 463ms/step - loss: 0.2069 - mean_IOU_gpu: 0.6587 - dice_metric: 0.7823 - val_loss: 0.1773 - val_mean_IOU_gpu: 0.6959 - val_dice_metric: 0.8102
# Epoch 70/500
# 99/99 [==============================] - 43s 435ms/step - loss: 0.2739 - mean_IOU_gpu: 0.6167 - dice_metric: 0.7412 - val_loss: 0.1803 - val_mean_IOU_gpu: 0.6716 - val_dice_metric: 0.7998
# Epoch 71/500
# 99/99 [==============================] - 43s 433ms/step - loss: 0.2267 - mean_IOU_gpu: 0.6431 - dice_metric: 0.7663 - val_loss: 0.2260 - val_mean_IOU_gpu: 0.6015 - val_dice_metric: 0.7427
# Epoch 72/500
# 99/99 [==============================] - 38s 383ms/step - loss: 0.2773 - mean_IOU_gpu: 0.6110 - dice_metric: 0.7379 - val_loss: 0.2448 - val_mean_IOU_gpu: 0.5876 - val_dice_metric: 0.7337
# Epoch 73/500
# 99/99 [==============================] - 38s 383ms/step - loss: 0.1765 - mean_IOU_gpu: 0.6896 - dice_metric: 0.8081 - val_loss: 0.1506 - val_mean_IOU_gpu: 0.7152 - val_dice_metric: 0.8298
# Epoch 74/500
# 99/99 [==============================] - 43s 436ms/step - loss: 0.1837 - mean_IOU_gpu: 0.6800 - dice_metric: 0.8007 - val_loss: 0.2138 - val_mean_IOU_gpu: 0.6226 - val_dice_metric: 0.7637
# Epoch 75/500
# 99/99 [==============================] - 46s 466ms/step - loss: 0.2385 - mean_IOU_gpu: 0.6314 - dice_metric: 0.7602 - val_loss: 0.2050 - val_mean_IOU_gpu: 0.6214 - val_dice_metric: 0.7619
# Epoch 76/500
# 99/99 [==============================] - 38s 385ms/step - loss: 0.1968 - mean_IOU_gpu: 0.6627 - dice_metric: 0.7885 - val_loss: 0.2383 - val_mean_IOU_gpu: 0.5993 - val_dice_metric: 0.7423
# Epoch 77/500
# 99/99 [==============================] - 38s 387ms/step - loss: 0.2486 - mean_IOU_gpu: 0.6286 - dice_metric: 0.7548 - val_loss: 0.1507 - val_mean_IOU_gpu: 0.7110 - val_dice_metric: 0.8287
# Epoch 78/500
# 99/99 [==============================] - 36s 362ms/step - loss: 0.2051 - mean_IOU_gpu: 0.6738 - dice_metric: 0.7923 - val_loss: 0.1483 - val_mean_IOU_gpu: 0.7209 - val_dice_metric: 0.8335
# Epoch 79/500
# 99/99 [==============================] - 36s 361ms/step - loss: 0.1912 - mean_IOU_gpu: 0.6704 - dice_metric: 0.7943 - val_loss: 0.1435 - val_mean_IOU_gpu: 0.7285 - val_dice_metric: 0.8381
# Epoch 80/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.1707 - mean_IOU_gpu: 0.6954 - dice_metric: 0.8128 - val_loss: 0.1732 - val_mean_IOU_gpu: 0.6749 - val_dice_metric: 0.8035
# Epoch 81/500
# 99/99 [==============================] - 36s 362ms/step - loss: 0.1635 - mean_IOU_gpu: 0.7053 - dice_metric: 0.8203 - val_loss: 0.1486 - val_mean_IOU_gpu: 0.7164 - val_dice_metric: 0.8319
# Epoch 82/500
# 99/99 [==============================] - 41s 413ms/step - loss: 0.1884 - mean_IOU_gpu: 0.6719 - dice_metric: 0.7965 - val_loss: 0.1483 - val_mean_IOU_gpu: 0.7175 - val_dice_metric: 0.8306
# Epoch 83/500
# 99/99 [==============================] - 40s 402ms/step - loss: 0.1758 - mean_IOU_gpu: 0.7020 - dice_metric: 0.8136 - val_loss: 0.1828 - val_mean_IOU_gpu: 0.6633 - val_dice_metric: 0.7947
# Epoch 84/500
# 99/99 [==============================] - 37s 378ms/step - loss: 0.1966 - mean_IOU_gpu: 0.6708 - dice_metric: 0.7941 - val_loss: 0.1751 - val_mean_IOU_gpu: 0.6710 - val_dice_metric: 0.8009
# Epoch 85/500
# 99/99 [==============================] - 37s 376ms/step - loss: 0.1808 - mean_IOU_gpu: 0.6795 - dice_metric: 0.8020 - val_loss: 0.1347 - val_mean_IOU_gpu: 0.7412 - val_dice_metric: 0.8464
# Epoch 86/500
# 99/99 [==============================] - 37s 372ms/step - loss: 0.1689 - mean_IOU_gpu: 0.7006 - dice_metric: 0.8158 - val_loss: 0.1417 - val_mean_IOU_gpu: 0.7310 - val_dice_metric: 0.8395
# Epoch 87/500
# 99/99 [==============================] - 39s 398ms/step - loss: 0.2255 - mean_IOU_gpu: 0.6675 - dice_metric: 0.7820 - val_loss: 0.3077 - val_mean_IOU_gpu: 0.5525 - val_dice_metric: 0.6949
# Epoch 88/500
# 99/99 [==============================] - 38s 380ms/step - loss: 0.2245 - mean_IOU_gpu: 0.6560 - dice_metric: 0.7765 - val_loss: 0.4634 - val_mean_IOU_gpu: 0.4351 - val_dice_metric: 0.5766
# Epoch 89/500
# 99/99 [==============================] - 44s 440ms/step - loss: 0.1726 - mean_IOU_gpu: 0.7041 - dice_metric: 0.8152 - val_loss: 0.1385 - val_mean_IOU_gpu: 0.7374 - val_dice_metric: 0.8444
# Epoch 90/500
# 99/99 [==============================] - 51s 514ms/step - loss: 0.1531 - mean_IOU_gpu: 0.7205 - dice_metric: 0.8309 - val_loss: 0.1582 - val_mean_IOU_gpu: 0.6948 - val_dice_metric: 0.8176
# Epoch 91/500
# 99/99 [==============================] - 38s 387ms/step - loss: 0.1745 - mean_IOU_gpu: 0.6879 - dice_metric: 0.8086 - val_loss: 0.1464 - val_mean_IOU_gpu: 0.7141 - val_dice_metric: 0.8312
# Epoch 92/500
# 99/99 [==============================] - 38s 380ms/step - loss: 0.1636 - mean_IOU_gpu: 0.6984 - dice_metric: 0.8166 - val_loss: 0.1322 - val_mean_IOU_gpu: 0.7471 - val_dice_metric: 0.8509
# Epoch 93/500
# 99/99 [==============================] - 37s 372ms/step - loss: 0.1656 - mean_IOU_gpu: 0.7005 - dice_metric: 0.8174 - val_loss: 0.1493 - val_mean_IOU_gpu: 0.7105 - val_dice_metric: 0.8285
# Epoch 94/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.1508 - mean_IOU_gpu: 0.7148 - dice_metric: 0.8290 - val_loss: 0.1391 - val_mean_IOU_gpu: 0.7356 - val_dice_metric: 0.8427
# Epoch 95/500
# 99/99 [==============================] - 37s 373ms/step - loss: 0.1594 - mean_IOU_gpu: 0.7016 - dice_metric: 0.8202 - val_loss: 0.1335 - val_mean_IOU_gpu: 0.7460 - val_dice_metric: 0.8497
# Epoch 96/500
# 99/99 [==============================] - 37s 374ms/step - loss: 0.1491 - mean_IOU_gpu: 0.7223 - dice_metric: 0.8323 - val_loss: 0.1430 - val_mean_IOU_gpu: 0.7164 - val_dice_metric: 0.8324
# Epoch 97/500
# 99/99 [==============================] - 37s 375ms/step - loss: 0.1811 - mean_IOU_gpu: 0.6848 - dice_metric: 0.8041 - val_loss: 0.1323 - val_mean_IOU_gpu: 0.7516 - val_dice_metric: 0.8528
# Epoch 98/500
# 99/99 [==============================] - 39s 392ms/step - loss: 0.1526 - mean_IOU_gpu: 0.7194 - dice_metric: 0.8296 - val_loss: 0.1521 - val_mean_IOU_gpu: 0.7049 - val_dice_metric: 0.8245
# Epoch 99/500
# 99/99 [==============================] - 38s 379ms/step - loss: 0.1449 - mean_IOU_gpu: 0.7320 - dice_metric: 0.8387 - val_loss: 0.1741 - val_mean_IOU_gpu: 0.6724 - val_dice_metric: 0.8015
# Epoch 100/500
# 99/99 [==============================] - 37s 377ms/step - loss: 0.1600 - mean_IOU_gpu: 0.7139 - dice_metric: 0.8252 - val_loss: 0.2101 - val_mean_IOU_gpu: 0.6285 - val_dice_metric: 0.7685
# Epoch 101/500
# 99/99 [==============================] - 38s 385ms/step - loss: 0.1556 - mean_IOU_gpu: 0.7097 - dice_metric: 0.8240 - val_loss: 0.1330 - val_mean_IOU_gpu: 0.7446 - val_dice_metric: 0.8491
# Epoch 102/500
# 99/99 [==============================] - 42s 429ms/step - loss: 0.1528 - mean_IOU_gpu: 0.7170 - dice_metric: 0.8296 - val_loss: 0.1537 - val_mean_IOU_gpu: 0.7014 - val_dice_metric: 0.8225
# Epoch 103/500
# 99/99 [==============================] - 40s 403ms/step - loss: 0.1459 - mean_IOU_gpu: 0.7211 - dice_metric: 0.8335 - val_loss: 0.1249 - val_mean_IOU_gpu: 0.7578 - val_dice_metric: 0.8582
# Epoch 104/500
# 99/99 [==============================] - 35s 356ms/step - loss: 0.1375 - mean_IOU_gpu: 0.7405 - dice_metric: 0.8453 - val_loss: 0.1741 - val_mean_IOU_gpu: 0.6688 - val_dice_metric: 0.7998
# Epoch 105/500
# 99/99 [==============================] - 34s 342ms/step - loss: 0.1570 - mean_IOU_gpu: 0.7098 - dice_metric: 0.8244 - val_loss: 0.1366 - val_mean_IOU_gpu: 0.7290 - val_dice_metric: 0.8405
# Epoch 106/500
# 99/99 [==============================] - 34s 341ms/step - loss: 0.2178 - mean_IOU_gpu: 0.6514 - dice_metric: 0.7740 - val_loss: 0.1585 - val_mean_IOU_gpu: 0.7044 - val_dice_metric: 0.8189
# Epoch 107/500
# 99/99 [==============================] - 34s 342ms/step - loss: 0.1746 - mean_IOU_gpu: 0.6889 - dice_metric: 0.8087 - val_loss: 0.1310 - val_mean_IOU_gpu: 0.7340 - val_dice_metric: 0.8441
# Epoch 108/500
# 99/99 [==============================] - 34s 340ms/step - loss: 0.1399 - mean_IOU_gpu: 0.7327 - dice_metric: 0.8407 - val_loss: 0.1299 - val_mean_IOU_gpu: 0.7398 - val_dice_metric: 0.8471
# Epoch 109/500
# 99/99 [==============================] - 34s 339ms/step - loss: 0.1612 - mean_IOU_gpu: 0.7019 - dice_metric: 0.8184 - val_loss: 0.1412 - val_mean_IOU_gpu: 0.7265 - val_dice_metric: 0.8370
# Epoch 110/500
# 99/99 [==============================] - 34s 341ms/step - loss: 0.1579 - mean_IOU_gpu: 0.7047 - dice_metric: 0.8223 - val_loss: 0.1464 - val_mean_IOU_gpu: 0.7129 - val_dice_metric: 0.8301
# Epoch 111/500
# 99/99 [==============================] - 34s 342ms/step - loss: 0.1445 - mean_IOU_gpu: 0.7258 - dice_metric: 0.8358 - val_loss: 0.1285 - val_mean_IOU_gpu: 0.7489 - val_dice_metric: 0.8526
# Epoch 112/500
# 99/99 [==============================] - 36s 365ms/step - loss: 0.1723 - mean_IOU_gpu: 0.6941 - dice_metric: 0.8109 - val_loss: 0.1377 - val_mean_IOU_gpu: 0.7361 - val_dice_metric: 0.8435
# Epoch 113/500
# 99/99 [==============================] - 40s 400ms/step - loss: 0.1344 - mean_IOU_gpu: 0.7390 - dice_metric: 0.8453 - val_loss: 0.1383 - val_mean_IOU_gpu: 0.7260 - val_dice_metric: 0.8387
# Epoch 114/500
# 99/99 [==============================] - 42s 425ms/step - loss: 0.1491 - mean_IOU_gpu: 0.7225 - dice_metric: 0.8326 - val_loss: 0.1691 - val_mean_IOU_gpu: 0.6771 - val_dice_metric: 0.8057
# Epoch 115/500
# 99/99 [==============================] - 37s 376ms/step - loss: 0.1325 - mean_IOU_gpu: 0.7367 - dice_metric: 0.8457 - val_loss: 0.1287 - val_mean_IOU_gpu: 0.7451 - val_dice_metric: 0.8498
# Epoch 116/500
# 99/99 [==============================] - 38s 380ms/step - loss: 0.1364 - mean_IOU_gpu: 0.7356 - dice_metric: 0.8427 - val_loss: 0.1441 - val_mean_IOU_gpu: 0.7228 - val_dice_metric: 0.8360
# Epoch 117/500
# 99/99 [==============================] - 39s 394ms/step - loss: 0.1308 - mean_IOU_gpu: 0.7457 - dice_metric: 0.8490 - val_loss: 0.1284 - val_mean_IOU_gpu: 0.7451 - val_dice_metric: 0.8507
# Epoch 118/500
# 99/99 [==============================] - 38s 380ms/step - loss: 0.2011 - mean_IOU_gpu: 0.6863 - dice_metric: 0.7999 - val_loss: 0.3809 - val_mean_IOU_gpu: 0.4746 - val_dice_metric: 0.6180
# Epoch 119/500
# 99/99 [==============================] - 37s 374ms/step - loss: 0.1643 - mean_IOU_gpu: 0.7029 - dice_metric: 0.8182 - val_loss: 0.1290 - val_mean_IOU_gpu: 0.7437 - val_dice_metric: 0.8503
# Epoch 120/500
# 99/99 [==============================] - 36s 367ms/step - loss: 0.1519 - mean_IOU_gpu: 0.7119 - dice_metric: 0.8269 - val_loss: 0.1279 - val_mean_IOU_gpu: 0.7461 - val_dice_metric: 0.8516
# Epoch 121/500
# 99/99 [==============================] - 36s 364ms/step - loss: 0.1497 - mean_IOU_gpu: 0.7167 - dice_metric: 0.8297 - val_loss: 0.1317 - val_mean_IOU_gpu: 0.7406 - val_dice_metric: 0.8481
# Epoch 122/500
# 99/99 [==============================] - 37s 375ms/step - loss: 0.1644 - mean_IOU_gpu: 0.7051 - dice_metric: 0.8185 - val_loss: 0.1978 - val_mean_IOU_gpu: 0.6386 - val_dice_metric: 0.7771
# Epoch 123/500
# 99/99 [==============================] - 38s 386ms/step - loss: 0.1503 - mean_IOU_gpu: 0.7192 - dice_metric: 0.8304 - val_loss: 0.1360 - val_mean_IOU_gpu: 0.7378 - val_dice_metric: 0.8445
# Epoch 124/500
# 99/99 [==============================] - 36s 368ms/step - loss: 0.1576 - mean_IOU_gpu: 0.7070 - dice_metric: 0.8230 - val_loss: 0.1296 - val_mean_IOU_gpu: 0.7445 - val_dice_metric: 0.8498
# Epoch 125/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.1375 - mean_IOU_gpu: 0.7334 - dice_metric: 0.8422 - val_loss: 0.1316 - val_mean_IOU_gpu: 0.7350 - val_dice_metric: 0.8448
# Epoch 126/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1502 - mean_IOU_gpu: 0.7158 - dice_metric: 0.8288 - val_loss: 0.1301 - val_mean_IOU_gpu: 0.7360 - val_dice_metric: 0.8459
# Epoch 127/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1332 - mean_IOU_gpu: 0.7403 - dice_metric: 0.8464 - val_loss: 0.1323 - val_mean_IOU_gpu: 0.7338 - val_dice_metric: 0.8444
# Epoch 128/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1554 - mean_IOU_gpu: 0.7122 - dice_metric: 0.8256 - val_loss: 0.1258 - val_mean_IOU_gpu: 0.7525 - val_dice_metric: 0.8561
# Epoch 129/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1231 - mean_IOU_gpu: 0.7572 - dice_metric: 0.8572 - val_loss: 0.1280 - val_mean_IOU_gpu: 0.7443 - val_dice_metric: 0.8509
# Epoch 130/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1801 - mean_IOU_gpu: 0.7093 - dice_metric: 0.8155 - val_loss: 0.1946 - val_mean_IOU_gpu: 0.6732 - val_dice_metric: 0.7925
# Epoch 131/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1690 - mean_IOU_gpu: 0.7005 - dice_metric: 0.8156 - val_loss: 0.1682 - val_mean_IOU_gpu: 0.6692 - val_dice_metric: 0.7990
# Epoch 132/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1520 - mean_IOU_gpu: 0.7150 - dice_metric: 0.8275 - val_loss: 0.1602 - val_mean_IOU_gpu: 0.6832 - val_dice_metric: 0.8099
# Epoch 133/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1393 - mean_IOU_gpu: 0.7362 - dice_metric: 0.8421 - val_loss: 0.1289 - val_mean_IOU_gpu: 0.7506 - val_dice_metric: 0.8531
# Epoch 134/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1314 - mean_IOU_gpu: 0.7400 - dice_metric: 0.8464 - val_loss: 0.1372 - val_mean_IOU_gpu: 0.7290 - val_dice_metric: 0.8409
# Epoch 135/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1394 - mean_IOU_gpu: 0.7323 - dice_metric: 0.8405 - val_loss: 0.1278 - val_mean_IOU_gpu: 0.7491 - val_dice_metric: 0.8526
# Epoch 136/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1399 - mean_IOU_gpu: 0.7313 - dice_metric: 0.8398 - val_loss: 0.1345 - val_mean_IOU_gpu: 0.7391 - val_dice_metric: 0.8454
# Epoch 137/500
# 99/99 [==============================] - 35s 351ms/step - loss: 0.1421 - mean_IOU_gpu: 0.7266 - dice_metric: 0.8356 - val_loss: 0.1189 - val_mean_IOU_gpu: 0.7640 - val_dice_metric: 0.8626
# Epoch 138/500
# 99/99 [==============================] - 35s 352ms/step - loss: 0.1430 - mean_IOU_gpu: 0.7255 - dice_metric: 0.8356 - val_loss: 0.1263 - val_mean_IOU_gpu: 0.7494 - val_dice_metric: 0.8524
# Epoch 139/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1238 - mean_IOU_gpu: 0.7499 - dice_metric: 0.8536 - val_loss: 0.1192 - val_mean_IOU_gpu: 0.7633 - val_dice_metric: 0.8621
# Epoch 140/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1598 - mean_IOU_gpu: 0.7137 - dice_metric: 0.8238 - val_loss: 0.1168 - val_mean_IOU_gpu: 0.7619 - val_dice_metric: 0.8620
# Epoch 141/500
# 99/99 [==============================] - 34s 345ms/step - loss: 0.1441 - mean_IOU_gpu: 0.7248 - dice_metric: 0.8347 - val_loss: 0.1178 - val_mean_IOU_gpu: 0.7575 - val_dice_metric: 0.8594
# Epoch 142/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1287 - mean_IOU_gpu: 0.7478 - dice_metric: 0.8517 - val_loss: 0.1325 - val_mean_IOU_gpu: 0.7438 - val_dice_metric: 0.8479
# Epoch 143/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1451 - mean_IOU_gpu: 0.7275 - dice_metric: 0.8359 - val_loss: 0.1210 - val_mean_IOU_gpu: 0.7567 - val_dice_metric: 0.8580
# Epoch 144/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1315 - mean_IOU_gpu: 0.7397 - dice_metric: 0.8463 - val_loss: 0.1189 - val_mean_IOU_gpu: 0.7603 - val_dice_metric: 0.8609
# Epoch 145/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1378 - mean_IOU_gpu: 0.7366 - dice_metric: 0.8422 - val_loss: 0.1179 - val_mean_IOU_gpu: 0.7564 - val_dice_metric: 0.8591
# Epoch 146/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1242 - mean_IOU_gpu: 0.7479 - dice_metric: 0.8526 - val_loss: 0.1195 - val_mean_IOU_gpu: 0.7578 - val_dice_metric: 0.8588
# Epoch 147/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1283 - mean_IOU_gpu: 0.7426 - dice_metric: 0.8492 - val_loss: 0.1228 - val_mean_IOU_gpu: 0.7417 - val_dice_metric: 0.8504
# Epoch 148/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1256 - mean_IOU_gpu: 0.7496 - dice_metric: 0.8532 - val_loss: 0.1151 - val_mean_IOU_gpu: 0.7637 - val_dice_metric: 0.8629
# Epoch 149/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1164 - mean_IOU_gpu: 0.7645 - dice_metric: 0.8630 - val_loss: 0.1227 - val_mean_IOU_gpu: 0.7509 - val_dice_metric: 0.8551
# Epoch 150/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1321 - mean_IOU_gpu: 0.7416 - dice_metric: 0.8467 - val_loss: 0.1127 - val_mean_IOU_gpu: 0.7731 - val_dice_metric: 0.8686
# Epoch 151/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1354 - mean_IOU_gpu: 0.7390 - dice_metric: 0.8450 - val_loss: 0.1112 - val_mean_IOU_gpu: 0.7639 - val_dice_metric: 0.8645
# Epoch 152/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1528 - mean_IOU_gpu: 0.7201 - dice_metric: 0.8282 - val_loss: 0.1827 - val_mean_IOU_gpu: 0.6571 - val_dice_metric: 0.7902
# Epoch 153/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1334 - mean_IOU_gpu: 0.7404 - dice_metric: 0.8465 - val_loss: 0.1211 - val_mean_IOU_gpu: 0.7577 - val_dice_metric: 0.8586
# Epoch 154/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1512 - mean_IOU_gpu: 0.7214 - dice_metric: 0.8316 - val_loss: 0.1187 - val_mean_IOU_gpu: 0.7551 - val_dice_metric: 0.8581
# Epoch 155/500
# 99/99 [==============================] - 34s 345ms/step - loss: 0.1363 - mean_IOU_gpu: 0.7365 - dice_metric: 0.8433 - val_loss: 0.1159 - val_mean_IOU_gpu: 0.7605 - val_dice_metric: 0.8619
# Epoch 156/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1304 - mean_IOU_gpu: 0.7432 - dice_metric: 0.8485 - val_loss: 0.1317 - val_mean_IOU_gpu: 0.7490 - val_dice_metric: 0.8505
# Epoch 157/500
# 99/99 [==============================] - 33s 338ms/step - loss: 0.1360 - mean_IOU_gpu: 0.7418 - dice_metric: 0.8455 - val_loss: 0.1510 - val_mean_IOU_gpu: 0.7045 - val_dice_metric: 0.8250
# Epoch 158/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.1331 - mean_IOU_gpu: 0.7407 - dice_metric: 0.8459 - val_loss: 0.1302 - val_mean_IOU_gpu: 0.7348 - val_dice_metric: 0.8453
# Epoch 159/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.1340 - mean_IOU_gpu: 0.7412 - dice_metric: 0.8447 - val_loss: 0.1559 - val_mean_IOU_gpu: 0.7108 - val_dice_metric: 0.8236
# Epoch 160/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.1420 - mean_IOU_gpu: 0.7292 - dice_metric: 0.8380 - val_loss: 0.1158 - val_mean_IOU_gpu: 0.7650 - val_dice_metric: 0.8641
# Epoch 161/500
# 99/99 [==============================] - 33s 329ms/step - loss: 0.1274 - mean_IOU_gpu: 0.7505 - dice_metric: 0.8530 - val_loss: 0.1141 - val_mean_IOU_gpu: 0.7641 - val_dice_metric: 0.8644
# Epoch 162/500
# 99/99 [==============================] - 32s 325ms/step - loss: 0.1257 - mean_IOU_gpu: 0.7472 - dice_metric: 0.8516 - val_loss: 0.1193 - val_mean_IOU_gpu: 0.7576 - val_dice_metric: 0.8599
# Epoch 163/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.1287 - mean_IOU_gpu: 0.7490 - dice_metric: 0.8522 - val_loss: 0.1099 - val_mean_IOU_gpu: 0.7759 - val_dice_metric: 0.8709
# Epoch 164/500
# 99/99 [==============================] - 32s 322ms/step - loss: 0.1332 - mean_IOU_gpu: 0.7397 - dice_metric: 0.8452 - val_loss: 0.1104 - val_mean_IOU_gpu: 0.7718 - val_dice_metric: 0.8683
# Epoch 165/500
# 99/99 [==============================] - 32s 325ms/step - loss: 0.1276 - mean_IOU_gpu: 0.7462 - dice_metric: 0.8507 - val_loss: 0.1524 - val_mean_IOU_gpu: 0.7198 - val_dice_metric: 0.8294
# Epoch 166/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.1261 - mean_IOU_gpu: 0.7522 - dice_metric: 0.8536 - val_loss: 0.1161 - val_mean_IOU_gpu: 0.7653 - val_dice_metric: 0.8637
# Epoch 167/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.1249 - mean_IOU_gpu: 0.7507 - dice_metric: 0.8537 - val_loss: 0.1162 - val_mean_IOU_gpu: 0.7636 - val_dice_metric: 0.8631
# Epoch 168/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.1623 - mean_IOU_gpu: 0.7078 - dice_metric: 0.8208 - val_loss: 0.1219 - val_mean_IOU_gpu: 0.7553 - val_dice_metric: 0.8564
# Epoch 169/500
# 99/99 [==============================] - 32s 322ms/step - loss: 0.1300 - mean_IOU_gpu: 0.7433 - dice_metric: 0.8488 - val_loss: 0.1151 - val_mean_IOU_gpu: 0.7636 - val_dice_metric: 0.8637
# Epoch 170/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.1504 - mean_IOU_gpu: 0.7370 - dice_metric: 0.8379 - val_loss: 0.1447 - val_mean_IOU_gpu: 0.7153 - val_dice_metric: 0.8291
# Epoch 171/500
# 99/99 [==============================] - 32s 322ms/step - loss: 0.1872 - mean_IOU_gpu: 0.7002 - dice_metric: 0.8133 - val_loss: 0.1203 - val_mean_IOU_gpu: 0.7606 - val_dice_metric: 0.8606
# Epoch 172/500
# 99/99 [==============================] - 32s 322ms/step - loss: 0.1357 - mean_IOU_gpu: 0.7402 - dice_metric: 0.8441 - val_loss: 0.1266 - val_mean_IOU_gpu: 0.7480 - val_dice_metric: 0.8513
# Epoch 173/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.1668 - mean_IOU_gpu: 0.7084 - dice_metric: 0.8178 - val_loss: 0.1231 - val_mean_IOU_gpu: 0.7534 - val_dice_metric: 0.8565
# Epoch 174/500
# 99/99 [==============================] - 32s 322ms/step - loss: 0.1245 - mean_IOU_gpu: 0.7492 - dice_metric: 0.8528 - val_loss: 0.1127 - val_mean_IOU_gpu: 0.7710 - val_dice_metric: 0.8685
# Epoch 175/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.1364 - mean_IOU_gpu: 0.7343 - dice_metric: 0.8418 - val_loss: 0.1285 - val_mean_IOU_gpu: 0.7363 - val_dice_metric: 0.8463
# Epoch 176/500
# 99/99 [==============================] - 32s 322ms/step - loss: 0.1271 - mean_IOU_gpu: 0.7460 - dice_metric: 0.8506 - val_loss: 0.1156 - val_mean_IOU_gpu: 0.7553 - val_dice_metric: 0.8590
# Epoch 177/500
# 99/99 [==============================] - 32s 325ms/step - loss: 0.1272 - mean_IOU_gpu: 0.7434 - dice_metric: 0.8490 - val_loss: 0.1179 - val_mean_IOU_gpu: 0.7608 - val_dice_metric: 0.8612
# Epoch 178/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.1212 - mean_IOU_gpu: 0.7556 - dice_metric: 0.8568 - val_loss: 0.1200 - val_mean_IOU_gpu: 0.7586 - val_dice_metric: 0.8594
# Epoch 179/500
# 99/99 [==============================] - 32s 325ms/step - loss: 0.1279 - mean_IOU_gpu: 0.7452 - dice_metric: 0.8502 - val_loss: 0.1122 - val_mean_IOU_gpu: 0.7664 - val_dice_metric: 0.8657
# Epoch 180/500
# 99/99 [==============================] - 36s 368ms/step - loss: 0.1295 - mean_IOU_gpu: 0.7463 - dice_metric: 0.8497 - val_loss: 0.1093 - val_mean_IOU_gpu: 0.7719 - val_dice_metric: 0.8690
# Epoch 181/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1268 - mean_IOU_gpu: 0.7468 - dice_metric: 0.8511 - val_loss: 0.1128 - val_mean_IOU_gpu: 0.7661 - val_dice_metric: 0.8649
# Epoch 182/500
# 99/99 [==============================] - 35s 354ms/step - loss: 0.1114 - mean_IOU_gpu: 0.7700 - dice_metric: 0.8673 - val_loss: 0.1055 - val_mean_IOU_gpu: 0.7776 - val_dice_metric: 0.8730
# Epoch 183/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1436 - mean_IOU_gpu: 0.7317 - dice_metric: 0.8384 - val_loss: 0.1148 - val_mean_IOU_gpu: 0.7576 - val_dice_metric: 0.8603
# Epoch 184/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1290 - mean_IOU_gpu: 0.7454 - dice_metric: 0.8499 - val_loss: 0.1056 - val_mean_IOU_gpu: 0.7785 - val_dice_metric: 0.8735
# Epoch 185/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1337 - mean_IOU_gpu: 0.7420 - dice_metric: 0.8458 - val_loss: 0.1859 - val_mean_IOU_gpu: 0.6831 - val_dice_metric: 0.8009
# Epoch 186/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1355 - mean_IOU_gpu: 0.7379 - dice_metric: 0.8436 - val_loss: 0.1289 - val_mean_IOU_gpu: 0.7321 - val_dice_metric: 0.8436
# Epoch 187/500
# 99/99 [==============================] - 35s 351ms/step - loss: 0.1576 - mean_IOU_gpu: 0.7102 - dice_metric: 0.8242 - val_loss: 0.1473 - val_mean_IOU_gpu: 0.7241 - val_dice_metric: 0.8342
# Epoch 188/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1763 - mean_IOU_gpu: 0.7062 - dice_metric: 0.8167 - val_loss: 0.1305 - val_mean_IOU_gpu: 0.7265 - val_dice_metric: 0.8401
# Epoch 189/500
# 99/99 [==============================] - 36s 364ms/step - loss: 0.1484 - mean_IOU_gpu: 0.7186 - dice_metric: 0.8306 - val_loss: 0.1173 - val_mean_IOU_gpu: 0.7462 - val_dice_metric: 0.8533
# Epoch 190/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1159 - mean_IOU_gpu: 0.7699 - dice_metric: 0.8650 - val_loss: 0.1305 - val_mean_IOU_gpu: 0.7477 - val_dice_metric: 0.8506
# Epoch 191/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1234 - mean_IOU_gpu: 0.7521 - dice_metric: 0.8544 - val_loss: 0.1056 - val_mean_IOU_gpu: 0.7744 - val_dice_metric: 0.8710
# Epoch 192/500
# 99/99 [==============================] - 35s 351ms/step - loss: 0.1496 - mean_IOU_gpu: 0.7217 - dice_metric: 0.8310 - val_loss: 0.1100 - val_mean_IOU_gpu: 0.7723 - val_dice_metric: 0.8690
# Epoch 193/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1224 - mean_IOU_gpu: 0.7580 - dice_metric: 0.8580 - val_loss: 0.1050 - val_mean_IOU_gpu: 0.7789 - val_dice_metric: 0.8738
# Epoch 194/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1095 - mean_IOU_gpu: 0.7732 - dice_metric: 0.8695 - val_loss: 0.1167 - val_mean_IOU_gpu: 0.7643 - val_dice_metric: 0.8626
# Epoch 195/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1248 - mean_IOU_gpu: 0.7501 - dice_metric: 0.8540 - val_loss: 0.1045 - val_mean_IOU_gpu: 0.7802 - val_dice_metric: 0.8747
# Epoch 196/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1297 - mean_IOU_gpu: 0.7446 - dice_metric: 0.8500 - val_loss: 0.1191 - val_mean_IOU_gpu: 0.7631 - val_dice_metric: 0.8618
# Epoch 197/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.1245 - mean_IOU_gpu: 0.7498 - dice_metric: 0.8532 - val_loss: 0.1126 - val_mean_IOU_gpu: 0.7726 - val_dice_metric: 0.8682
# Epoch 198/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1182 - mean_IOU_gpu: 0.7612 - dice_metric: 0.8606 - val_loss: 0.1221 - val_mean_IOU_gpu: 0.7604 - val_dice_metric: 0.8597
# Epoch 199/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1169 - mean_IOU_gpu: 0.7645 - dice_metric: 0.8631 - val_loss: 0.1157 - val_mean_IOU_gpu: 0.7694 - val_dice_metric: 0.8656
# Epoch 200/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1246 - mean_IOU_gpu: 0.7533 - dice_metric: 0.8553 - val_loss: 0.1113 - val_mean_IOU_gpu: 0.7645 - val_dice_metric: 0.8648
# Epoch 201/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1439 - mean_IOU_gpu: 0.7302 - dice_metric: 0.8365 - val_loss: 0.1149 - val_mean_IOU_gpu: 0.7596 - val_dice_metric: 0.8614
# Epoch 202/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.1209 - mean_IOU_gpu: 0.7603 - dice_metric: 0.8585 - val_loss: 0.1207 - val_mean_IOU_gpu: 0.7616 - val_dice_metric: 0.8600
# Epoch 203/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1213 - mean_IOU_gpu: 0.7601 - dice_metric: 0.8592 - val_loss: 0.1305 - val_mean_IOU_gpu: 0.7499 - val_dice_metric: 0.8515
# Epoch 204/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1247 - mean_IOU_gpu: 0.7515 - dice_metric: 0.8539 - val_loss: 0.1369 - val_mean_IOU_gpu: 0.7407 - val_dice_metric: 0.8451
# Epoch 205/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1243 - mean_IOU_gpu: 0.7538 - dice_metric: 0.8552 - val_loss: 0.1221 - val_mean_IOU_gpu: 0.7551 - val_dice_metric: 0.8563
# Epoch 206/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1055 - mean_IOU_gpu: 0.7772 - dice_metric: 0.8719 - val_loss: 0.1265 - val_mean_IOU_gpu: 0.7541 - val_dice_metric: 0.8548
# Epoch 207/500
# 99/99 [==============================] - 36s 362ms/step - loss: 0.1247 - mean_IOU_gpu: 0.7523 - dice_metric: 0.8546 - val_loss: 0.1231 - val_mean_IOU_gpu: 0.7565 - val_dice_metric: 0.8570
# Epoch 208/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1263 - mean_IOU_gpu: 0.7504 - dice_metric: 0.8523 - val_loss: 0.1135 - val_mean_IOU_gpu: 0.7700 - val_dice_metric: 0.8664
# Epoch 209/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1173 - mean_IOU_gpu: 0.7644 - dice_metric: 0.8630 - val_loss: 0.1336 - val_mean_IOU_gpu: 0.7453 - val_dice_metric: 0.8478
# Epoch 210/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1221 - mean_IOU_gpu: 0.7533 - dice_metric: 0.8560 - val_loss: 0.1060 - val_mean_IOU_gpu: 0.7785 - val_dice_metric: 0.8733
# Epoch 211/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1185 - mean_IOU_gpu: 0.7601 - dice_metric: 0.8602 - val_loss: 0.0998 - val_mean_IOU_gpu: 0.7876 - val_dice_metric: 0.8794
# Epoch 212/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1150 - mean_IOU_gpu: 0.7634 - dice_metric: 0.8624 - val_loss: 0.1306 - val_mean_IOU_gpu: 0.7493 - val_dice_metric: 0.8512
# Epoch 213/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1350 - mean_IOU_gpu: 0.7334 - dice_metric: 0.8420 - val_loss: 0.1100 - val_mean_IOU_gpu: 0.7652 - val_dice_metric: 0.8657
# Epoch 214/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1227 - mean_IOU_gpu: 0.7521 - dice_metric: 0.8548 - val_loss: 0.1065 - val_mean_IOU_gpu: 0.7783 - val_dice_metric: 0.8726
# Epoch 215/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1163 - mean_IOU_gpu: 0.7686 - dice_metric: 0.8639 - val_loss: 0.1128 - val_mean_IOU_gpu: 0.7688 - val_dice_metric: 0.8661
# Epoch 216/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1249 - mean_IOU_gpu: 0.7535 - dice_metric: 0.8551 - val_loss: 0.1074 - val_mean_IOU_gpu: 0.7773 - val_dice_metric: 0.8724
# Epoch 217/500
# 99/99 [==============================] - 34s 345ms/step - loss: 0.1193 - mean_IOU_gpu: 0.7579 - dice_metric: 0.8588 - val_loss: 0.1099 - val_mean_IOU_gpu: 0.7672 - val_dice_metric: 0.8667
# Epoch 218/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.1118 - mean_IOU_gpu: 0.7660 - dice_metric: 0.8650 - val_loss: 0.1193 - val_mean_IOU_gpu: 0.7600 - val_dice_metric: 0.8599
# Epoch 219/500
# 99/99 [==============================] - 34s 345ms/step - loss: 0.1095 - mean_IOU_gpu: 0.7747 - dice_metric: 0.8698 - val_loss: 0.1041 - val_mean_IOU_gpu: 0.7796 - val_dice_metric: 0.8743
# Epoch 220/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1181 - mean_IOU_gpu: 0.7637 - dice_metric: 0.8621 - val_loss: 0.1077 - val_mean_IOU_gpu: 0.7753 - val_dice_metric: 0.8710
# Epoch 221/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1218 - mean_IOU_gpu: 0.7551 - dice_metric: 0.8569 - val_loss: 0.1276 - val_mean_IOU_gpu: 0.7533 - val_dice_metric: 0.8538
# Epoch 222/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1207 - mean_IOU_gpu: 0.7551 - dice_metric: 0.8572 - val_loss: 0.1039 - val_mean_IOU_gpu: 0.7830 - val_dice_metric: 0.8758
# Epoch 223/500
# 99/99 [==============================] - 34s 345ms/step - loss: 0.1112 - mean_IOU_gpu: 0.7735 - dice_metric: 0.8688 - val_loss: 0.1057 - val_mean_IOU_gpu: 0.7734 - val_dice_metric: 0.8706
# Epoch 224/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1011 - mean_IOU_gpu: 0.7865 - dice_metric: 0.8778 - val_loss: 0.1083 - val_mean_IOU_gpu: 0.7764 - val_dice_metric: 0.8716
# Epoch 225/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1192 - mean_IOU_gpu: 0.7658 - dice_metric: 0.8623 - val_loss: 0.1605 - val_mean_IOU_gpu: 0.7168 - val_dice_metric: 0.8261
# Epoch 226/500
# 99/99 [==============================] - 34s 345ms/step - loss: 0.1370 - mean_IOU_gpu: 0.7378 - dice_metric: 0.8435 - val_loss: 0.1068 - val_mean_IOU_gpu: 0.7761 - val_dice_metric: 0.8718
# Epoch 227/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.1170 - mean_IOU_gpu: 0.7613 - dice_metric: 0.8613 - val_loss: 0.1105 - val_mean_IOU_gpu: 0.7766 - val_dice_metric: 0.8712
# Epoch 228/500
# 99/99 [==============================] - 34s 344ms/step - loss: 0.1093 - mean_IOU_gpu: 0.7761 - dice_metric: 0.8700 - val_loss: 0.1129 - val_mean_IOU_gpu: 0.7744 - val_dice_metric: 0.8697
# Epoch 229/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.1117 - mean_IOU_gpu: 0.7714 - dice_metric: 0.8673 - val_loss: 0.1352 - val_mean_IOU_gpu: 0.7431 - val_dice_metric: 0.8469
# Epoch 230/500
# 99/99 [==============================] - 35s 352ms/step - loss: 0.1234 - mean_IOU_gpu: 0.7548 - dice_metric: 0.8554 - val_loss: 0.1319 - val_mean_IOU_gpu: 0.7482 - val_dice_metric: 0.8503
# Epoch 231/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.1242 - mean_IOU_gpu: 0.7533 - dice_metric: 0.8549 - val_loss: 0.1138 - val_mean_IOU_gpu: 0.7683 - val_dice_metric: 0.8662
# Epoch 232/500
# 99/99 [==============================] - 35s 351ms/step - loss: 0.1228 - mean_IOU_gpu: 0.7537 - dice_metric: 0.8552 - val_loss: 0.1552 - val_mean_IOU_gpu: 0.7187 - val_dice_metric: 0.8284
# Epoch 233/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1423 - mean_IOU_gpu: 0.7323 - dice_metric: 0.8383 - val_loss: 0.1031 - val_mean_IOU_gpu: 0.7742 - val_dice_metric: 0.8716
# Epoch 234/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.1144 - mean_IOU_gpu: 0.7664 - dice_metric: 0.8645 - val_loss: 0.1080 - val_mean_IOU_gpu: 0.7761 - val_dice_metric: 0.8713
# Epoch 235/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.1188 - mean_IOU_gpu: 0.7638 - dice_metric: 0.8621 - val_loss: 0.1349 - val_mean_IOU_gpu: 0.7441 - val_dice_metric: 0.8469
# Epoch 236/500
# ...
# Epoch 422/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.1067 - mean_IOU_gpu: 0.7733 - dice_metric: 0.8692 - val_loss: 0.1106 - val_mean_IOU_gpu: 0.7712 - val_dice_metric: 0.8680
# Epoch 423/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.0909 - mean_IOU_gpu: 0.8027 - dice_metric: 0.8888 - val_loss: 0.1411 - val_mean_IOU_gpu: 0.7381 - val_dice_metric: 0.8433
# Epoch 424/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.0915 - mean_IOU_gpu: 0.8056 - dice_metric: 0.8897 - val_loss: 0.1091 - val_mean_IOU_gpu: 0.7761 - val_dice_metric: 0.8713
# Epoch 425/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.1025 - mean_IOU_gpu: 0.7844 - dice_metric: 0.8766 - val_loss: 0.1044 - val_mean_IOU_gpu: 0.7812 - val_dice_metric: 0.8749
# Epoch 426/500
# 99/99 [==============================] - 32s 321ms/step - loss: 0.0998 - mean_IOU_gpu: 0.7865 - dice_metric: 0.8784 - val_loss: 0.1091 - val_mean_IOU_gpu: 0.7795 - val_dice_metric: 0.8731
# Epoch 427/500
# 99/99 [==============================] - 32s 322ms/step - loss: 0.0976 - mean_IOU_gpu: 0.7935 - dice_metric: 0.8820 - val_loss: 0.1259 - val_mean_IOU_gpu: 0.7563 - val_dice_metric: 0.8563
# Epoch 428/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.0890 - mean_IOU_gpu: 0.8068 - dice_metric: 0.8912 - val_loss: 0.1065 - val_mean_IOU_gpu: 0.7823 - val_dice_metric: 0.8749
# Epoch 429/500
# 99/99 [==============================] - 33s 332ms/step - loss: 0.0930 - mean_IOU_gpu: 0.7956 - dice_metric: 0.8843 - val_loss: 0.1267 - val_mean_IOU_gpu: 0.7554 - val_dice_metric: 0.8558
# Epoch 430/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.0882 - mean_IOU_gpu: 0.8077 - dice_metric: 0.8914 - val_loss: 0.1266 - val_mean_IOU_gpu: 0.7563 - val_dice_metric: 0.8560
# Epoch 431/500
# 99/99 [==============================] - 32s 322ms/step - loss: 0.0905 - mean_IOU_gpu: 0.8014 - dice_metric: 0.8882 - val_loss: 0.1171 - val_mean_IOU_gpu: 0.7648 - val_dice_metric: 0.8631
# Epoch 432/500
# 99/99 [==============================] - 32s 323ms/step - loss: 0.0891 - mean_IOU_gpu: 0.8068 - dice_metric: 0.8909 - val_loss: 0.1070 - val_mean_IOU_gpu: 0.7813 - val_dice_metric: 0.8741
# Epoch 433/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.0925 - mean_IOU_gpu: 0.7998 - dice_metric: 0.8866 - val_loss: 0.1050 - val_mean_IOU_gpu: 0.7850 - val_dice_metric: 0.8766
# Epoch 434/500
# 99/99 [==============================] - 32s 324ms/step - loss: 0.0935 - mean_IOU_gpu: 0.7982 - dice_metric: 0.8856 - val_loss: 0.1141 - val_mean_IOU_gpu: 0.7705 - val_dice_metric: 0.8665
# Epoch 435/500
# 99/99 [==============================] - 36s 364ms/step - loss: 0.0923 - mean_IOU_gpu: 0.8007 - dice_metric: 0.8868 - val_loss: 0.1206 - val_mean_IOU_gpu: 0.7661 - val_dice_metric: 0.8633
# Epoch 436/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0983 - mean_IOU_gpu: 0.7908 - dice_metric: 0.8807 - val_loss: 0.1174 - val_mean_IOU_gpu: 0.7680 - val_dice_metric: 0.8647
# Epoch 437/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.1073 - mean_IOU_gpu: 0.7808 - dice_metric: 0.8721 - val_loss: 0.0992 - val_mean_IOU_gpu: 0.7858 - val_dice_metric: 0.8789
# Epoch 438/500
# 99/99 [==============================] - 37s 371ms/step - loss: 0.0966 - mean_IOU_gpu: 0.7938 - dice_metric: 0.8821 - val_loss: 0.1447 - val_mean_IOU_gpu: 0.7305 - val_dice_metric: 0.8385
# Epoch 439/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0971 - mean_IOU_gpu: 0.7911 - dice_metric: 0.8815 - val_loss: 0.1246 - val_mean_IOU_gpu: 0.7568 - val_dice_metric: 0.8573
# Epoch 440/500
# 99/99 [==============================] - 37s 371ms/step - loss: 0.0956 - mean_IOU_gpu: 0.7932 - dice_metric: 0.8831 - val_loss: 0.1265 - val_mean_IOU_gpu: 0.7548 - val_dice_metric: 0.8555
# Epoch 441/500
# 99/99 [==============================] - 37s 369ms/step - loss: 0.1045 - mean_IOU_gpu: 0.7811 - dice_metric: 0.8741 - val_loss: 0.1071 - val_mean_IOU_gpu: 0.7818 - val_dice_metric: 0.8747
# Epoch 442/500
# 99/99 [==============================] - 37s 376ms/step - loss: 0.0874 - mean_IOU_gpu: 0.8089 - dice_metric: 0.8921 - val_loss: 0.1265 - val_mean_IOU_gpu: 0.7548 - val_dice_metric: 0.8558
# Epoch 443/500
# 99/99 [==============================] - 37s 373ms/step - loss: 0.0883 - mean_IOU_gpu: 0.8045 - dice_metric: 0.8904 - val_loss: 0.1008 - val_mean_IOU_gpu: 0.7873 - val_dice_metric: 0.8791
# Epoch 444/500
# 99/99 [==============================] - 37s 371ms/step - loss: 0.0994 - mean_IOU_gpu: 0.7897 - dice_metric: 0.8799 - val_loss: 0.1185 - val_mean_IOU_gpu: 0.7659 - val_dice_metric: 0.8634
# Epoch 445/500
# 99/99 [==============================] - 37s 372ms/step - loss: 0.0891 - mean_IOU_gpu: 0.8035 - dice_metric: 0.8896 - val_loss: 0.1264 - val_mean_IOU_gpu: 0.7569 - val_dice_metric: 0.8568
# Epoch 446/500
# 99/99 [==============================] - 37s 376ms/step - loss: 0.0917 - mean_IOU_gpu: 0.7992 - dice_metric: 0.8869 - val_loss: 0.1050 - val_mean_IOU_gpu: 0.7845 - val_dice_metric: 0.8765
# Epoch 447/500
# 99/99 [==============================] - 36s 368ms/step - loss: 0.0953 - mean_IOU_gpu: 0.7980 - dice_metric: 0.8844 - val_loss: 0.1048 - val_mean_IOU_gpu: 0.7838 - val_dice_metric: 0.8763
# Epoch 448/500
# 99/99 [==============================] - 37s 372ms/step - loss: 0.0954 - mean_IOU_gpu: 0.7931 - dice_metric: 0.8828 - val_loss: 0.1135 - val_mean_IOU_gpu: 0.7746 - val_dice_metric: 0.8691
# Epoch 449/500
# 99/99 [==============================] - 37s 378ms/step - loss: 0.0852 - mean_IOU_gpu: 0.8120 - dice_metric: 0.8947 - val_loss: 0.1285 - val_mean_IOU_gpu: 0.7567 - val_dice_metric: 0.8563
# Epoch 450/500
# 99/99 [==============================] - 37s 369ms/step - loss: 0.0885 - mean_IOU_gpu: 0.8078 - dice_metric: 0.8915 - val_loss: 0.1014 - val_mean_IOU_gpu: 0.7865 - val_dice_metric: 0.8786
# Epoch 451/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0833 - mean_IOU_gpu: 0.8158 - dice_metric: 0.8968 - val_loss: 0.1107 - val_mean_IOU_gpu: 0.7756 - val_dice_metric: 0.8704
# Epoch 452/500
# 99/99 [==============================] - 37s 373ms/step - loss: 0.0985 - mean_IOU_gpu: 0.7909 - dice_metric: 0.8802 - val_loss: 0.1169 - val_mean_IOU_gpu: 0.7630 - val_dice_metric: 0.8628
# Epoch 453/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0926 - mean_IOU_gpu: 0.7976 - dice_metric: 0.8858 - val_loss: 0.1090 - val_mean_IOU_gpu: 0.7741 - val_dice_metric: 0.8705
# Epoch 454/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0858 - mean_IOU_gpu: 0.8103 - dice_metric: 0.8936 - val_loss: 0.1161 - val_mean_IOU_gpu: 0.7669 - val_dice_metric: 0.8646
# Epoch 455/500
# 99/99 [==============================] - 38s 379ms/step - loss: 0.0873 - mean_IOU_gpu: 0.8074 - dice_metric: 0.8917 - val_loss: 0.1074 - val_mean_IOU_gpu: 0.7803 - val_dice_metric: 0.8740
# Epoch 456/500
# 99/99 [==============================] - 36s 368ms/step - loss: 0.0972 - mean_IOU_gpu: 0.7945 - dice_metric: 0.8826 - val_loss: 0.1209 - val_mean_IOU_gpu: 0.7632 - val_dice_metric: 0.8616
# Epoch 457/500
# 99/99 [==============================] - 37s 369ms/step - loss: 0.0806 - mean_IOU_gpu: 0.8189 - dice_metric: 0.8987 - val_loss: 0.1223 - val_mean_IOU_gpu: 0.7595 - val_dice_metric: 0.8593
# Epoch 458/500
# 99/99 [==============================] - 37s 372ms/step - loss: 0.1008 - mean_IOU_gpu: 0.7867 - dice_metric: 0.8783 - val_loss: 0.1339 - val_mean_IOU_gpu: 0.7473 - val_dice_metric: 0.8496
# Epoch 459/500
# 99/99 [==============================] - 37s 372ms/step - loss: 0.0866 - mean_IOU_gpu: 0.8115 - dice_metric: 0.8940 - val_loss: 0.1232 - val_mean_IOU_gpu: 0.7581 - val_dice_metric: 0.8582
# Epoch 460/500
# 99/99 [==============================] - 37s 374ms/step - loss: 0.0903 - mean_IOU_gpu: 0.8029 - dice_metric: 0.8886 - val_loss: 0.1149 - val_mean_IOU_gpu: 0.7717 - val_dice_metric: 0.8675
# Epoch 461/500
# 99/99 [==============================] - 37s 373ms/step - loss: 0.0907 - mean_IOU_gpu: 0.8018 - dice_metric: 0.8877 - val_loss: 0.0996 - val_mean_IOU_gpu: 0.7920 - val_dice_metric: 0.8818
# Epoch 462/500
# 99/99 [==============================] - 38s 380ms/step - loss: 0.0947 - mean_IOU_gpu: 0.7949 - dice_metric: 0.8836 - val_loss: 0.0966 - val_mean_IOU_gpu: 0.7934 - val_dice_metric: 0.8834
# Epoch 463/500
# 99/99 [==============================] - 38s 386ms/step - loss: 0.0940 - mean_IOU_gpu: 0.7957 - dice_metric: 0.8837 - val_loss: 0.1008 - val_mean_IOU_gpu: 0.7899 - val_dice_metric: 0.8801
# Epoch 464/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0941 - mean_IOU_gpu: 0.7960 - dice_metric: 0.8842 - val_loss: 0.1187 - val_mean_IOU_gpu: 0.7636 - val_dice_metric: 0.8622
# Epoch 465/500
# 99/99 [==============================] - 37s 371ms/step - loss: 0.0961 - mean_IOU_gpu: 0.7937 - dice_metric: 0.8826 - val_loss: 0.1075 - val_mean_IOU_gpu: 0.7789 - val_dice_metric: 0.8729
# Epoch 466/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0868 - mean_IOU_gpu: 0.8090 - dice_metric: 0.8928 - val_loss: 0.1049 - val_mean_IOU_gpu: 0.7833 - val_dice_metric: 0.8759
# Epoch 467/500
# 99/99 [==============================] - 38s 386ms/step - loss: 0.0966 - mean_IOU_gpu: 0.7906 - dice_metric: 0.8811 - val_loss: 0.1082 - val_mean_IOU_gpu: 0.7804 - val_dice_metric: 0.8736
# Epoch 468/500
# 99/99 [==============================] - 37s 369ms/step - loss: 0.0832 - mean_IOU_gpu: 0.8143 - dice_metric: 0.8957 - val_loss: 0.1009 - val_mean_IOU_gpu: 0.7891 - val_dice_metric: 0.8802
# Epoch 469/500
# 99/99 [==============================] - 37s 369ms/step - loss: 0.0976 - mean_IOU_gpu: 0.7943 - dice_metric: 0.8827 - val_loss: 0.1057 - val_mean_IOU_gpu: 0.7803 - val_dice_metric: 0.8746
# Epoch 470/500
# 99/99 [==============================] - 37s 375ms/step - loss: 0.0988 - mean_IOU_gpu: 0.7908 - dice_metric: 0.8808 - val_loss: 0.1270 - val_mean_IOU_gpu: 0.7562 - val_dice_metric: 0.8565
# Epoch 471/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0967 - mean_IOU_gpu: 0.7920 - dice_metric: 0.8814 - val_loss: 0.1037 - val_mean_IOU_gpu: 0.7838 - val_dice_metric: 0.8765
# Epoch 472/500
# 99/99 [==============================] - 37s 374ms/step - loss: 0.0856 - mean_IOU_gpu: 0.8119 - dice_metric: 0.8941 - val_loss: 0.1137 - val_mean_IOU_gpu: 0.7730 - val_dice_metric: 0.8684
# Epoch 473/500
# 99/99 [==============================] - 37s 370ms/step - loss: 0.0977 - mean_IOU_gpu: 0.7900 - dice_metric: 0.8806 - val_loss: 0.0979 - val_mean_IOU_gpu: 0.7958 - val_dice_metric: 0.8843
# Epoch 474/500
# 99/99 [==============================] - 37s 377ms/step - loss: 0.0853 - mean_IOU_gpu: 0.8125 - dice_metric: 0.8946 - val_loss: 0.1314 - val_mean_IOU_gpu: 0.7485 - val_dice_metric: 0.8516
# Epoch 475/500
# 99/99 [==============================] - 36s 360ms/step - loss: 0.0889 - mean_IOU_gpu: 0.8070 - dice_metric: 0.8907 - val_loss: 0.1658 - val_mean_IOU_gpu: 0.7112 - val_dice_metric: 0.8232
# Epoch 476/500
# 99/99 [==============================] - 35s 351ms/step - loss: 0.0900 - mean_IOU_gpu: 0.8011 - dice_metric: 0.8880 - val_loss: 0.1172 - val_mean_IOU_gpu: 0.7699 - val_dice_metric: 0.8660
# Epoch 477/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.0959 - mean_IOU_gpu: 0.7928 - dice_metric: 0.8822 - val_loss: 0.0967 - val_mean_IOU_gpu: 0.7931 - val_dice_metric: 0.8830
# Epoch 478/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.0884 - mean_IOU_gpu: 0.8058 - dice_metric: 0.8904 - val_loss: 0.1139 - val_mean_IOU_gpu: 0.7749 - val_dice_metric: 0.8693
# Epoch 479/500
# 99/99 [==============================] - 35s 352ms/step - loss: 0.0904 - mean_IOU_gpu: 0.8031 - dice_metric: 0.8888 - val_loss: 0.1092 - val_mean_IOU_gpu: 0.7778 - val_dice_metric: 0.8720
# Epoch 480/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.0837 - mean_IOU_gpu: 0.8155 - dice_metric: 0.8967 - val_loss: 0.1370 - val_mean_IOU_gpu: 0.7449 - val_dice_metric: 0.8479
# Epoch 481/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.0982 - mean_IOU_gpu: 0.7915 - dice_metric: 0.8807 - val_loss: 0.1138 - val_mean_IOU_gpu: 0.7692 - val_dice_metric: 0.8664
# Epoch 482/500
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0893 - mean_IOU_gpu: 0.8040 - dice_metric: 0.8898 - val_loss: 0.1031 - val_mean_IOU_gpu: 0.7861 - val_dice_metric: 0.8778
# Epoch 483/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.0954 - mean_IOU_gpu: 0.7965 - dice_metric: 0.8846 - val_loss: 0.1006 - val_mean_IOU_gpu: 0.7841 - val_dice_metric: 0.8778
# Epoch 484/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.0924 - mean_IOU_gpu: 0.8017 - dice_metric: 0.8875 - val_loss: 0.1078 - val_mean_IOU_gpu: 0.7822 - val_dice_metric: 0.8746
# Epoch 485/500
# 99/99 [==============================] - 35s 354ms/step - loss: 0.1017 - mean_IOU_gpu: 0.7828 - dice_metric: 0.8753 - val_loss: 0.1053 - val_mean_IOU_gpu: 0.7825 - val_dice_metric: 0.8754
# Epoch 486/500
# 99/99 [==============================] - 35s 349ms/step - loss: 0.0961 - mean_IOU_gpu: 0.7951 - dice_metric: 0.8837 - val_loss: 0.1210 - val_mean_IOU_gpu: 0.7682 - val_dice_metric: 0.8640
# Epoch 487/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.0960 - mean_IOU_gpu: 0.7937 - dice_metric: 0.8821 - val_loss: 0.1229 - val_mean_IOU_gpu: 0.7622 - val_dice_metric: 0.8605
# Epoch 488/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.0889 - mean_IOU_gpu: 0.8093 - dice_metric: 0.8924 - val_loss: 0.1203 - val_mean_IOU_gpu: 0.7663 - val_dice_metric: 0.8634
# Epoch 489/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.0862 - mean_IOU_gpu: 0.8098 - dice_metric: 0.8930 - val_loss: 0.1283 - val_mean_IOU_gpu: 0.7558 - val_dice_metric: 0.8560
# Epoch 490/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.0978 - mean_IOU_gpu: 0.7905 - dice_metric: 0.8800 - val_loss: 0.1604 - val_mean_IOU_gpu: 0.7152 - val_dice_metric: 0.8264
# Epoch 491/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.1058 - mean_IOU_gpu: 0.7804 - dice_metric: 0.8736 - val_loss: 0.1296 - val_mean_IOU_gpu: 0.7542 - val_dice_metric: 0.8546
# Epoch 492/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.0817 - mean_IOU_gpu: 0.8171 - dice_metric: 0.8978 - val_loss: 0.1123 - val_mean_IOU_gpu: 0.7754 - val_dice_metric: 0.8700
# Epoch 493/500
# 99/99 [==============================] - 34s 347ms/step - loss: 0.0864 - mean_IOU_gpu: 0.8114 - dice_metric: 0.8942 - val_loss: 0.1399 - val_mean_IOU_gpu: 0.7427 - val_dice_metric: 0.8458
# Epoch 494/500
# 99/99 [==============================] - 34s 348ms/step - loss: 0.0908 - mean_IOU_gpu: 0.8052 - dice_metric: 0.8901 - val_loss: 0.1081 - val_mean_IOU_gpu: 0.7813 - val_dice_metric: 0.8741
# Epoch 495/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.0820 - mean_IOU_gpu: 0.8167 - dice_metric: 0.8975 - val_loss: 0.1203 - val_mean_IOU_gpu: 0.7661 - val_dice_metric: 0.8632
# Epoch 496/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.0862 - mean_IOU_gpu: 0.8102 - dice_metric: 0.8933 - val_loss: 0.0937 - val_mean_IOU_gpu: 0.7985 - val_dice_metric: 0.8865
# Epoch 497/500
# 99/99 [==============================] - 35s 351ms/step - loss: 0.0942 - mean_IOU_gpu: 0.7975 - dice_metric: 0.8850 - val_loss: 0.1247 - val_mean_IOU_gpu: 0.7607 - val_dice_metric: 0.8592
# Epoch 498/500
# 99/99 [==============================] - 34s 346ms/step - loss: 0.0912 - mean_IOU_gpu: 0.8034 - dice_metric: 0.8887 - val_loss: 0.1027 - val_mean_IOU_gpu: 0.7851 - val_dice_metric: 0.8777
# Epoch 499/500
# 99/99 [==============================] - 35s 350ms/step - loss: 0.0972 - mean_IOU_gpu: 0.7910 - dice_metric: 0.8812 - val_loss: 0.1306 - val_mean_IOU_gpu: 0.7521 - val_dice_metric: 0.8534
# Epoch 500/500
# 99/99 [==============================] - 35s 354ms/step - loss: 0.0915 - mean_IOU_gpu: 0.8038 - dice_metric: 0.8890 - val_loss: 0.1258 - val_mean_IOU_gpu: 0.7583 - val_dice_metric: 0.8574

# %% [markdown]
# ### Visual check

# %%
pred_iou, pred_dice = [], []
pred_cup = []

for i, img_no in enumerate(test_idx):
    print('image #{}'.format(img_no))
    img = red_channel_test[img_no]
    batch_X = X_valid[i:i + 1]
    batch_y = Y_valid[i:i + 1]
    
    pred = (model.predict(batch_X)[0, 0] > 0.5).astype(np.float64)
    pred_cup.append(pred)
    corr = th_to_tf_encoding(batch_y)[0, ..., 0]
    
    fig = plt.figure(figsize=(9, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(pred, cmap=plt.cm.Greys_r)
    ax.set_title('Predicted')
    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(corr, cmap=plt.cm.Greys_r)
    ax.set_title('Correct')
    ax = fig.add_subplot(1, 3, 3)
    #ax.imshow(img)
    ax.imshow(th_to_tf_encoding(batch_X)[0])
    ax.set_title('Image')
    plt.show()
    
    cur_iou = K.eval(mean_IOU_gpu(pred[None, None, ...], corr[None, None, ...]))
    cur_dice = K.eval(dice(pred[None, None, ...], corr[None, None, ...]))
    print('IOU: {}\nDice: {}'.format(cur_iou, cur_dice))
    pred_iou.append(cur_iou)
    pred_dice.append(cur_dice)
# Out:
# image #0
# IOU: 0.8563829660415649
# Dice: 0.9226361031518625
# image #1
# IOU: 0.8139097690582275
# Dice: 0.8974093264248705
# image #2
# IOU: 0.6455331444740295
# Dice: 0.7845884413309983
# image #3
# IOU: 0.8270270228385925
# Dice: 0.9053254437869822
# image #4
# IOU: 0.8703703880310059
# Dice: 0.9306930693069307
# image #5
# IOU: 0.9003868699073792
# Dice: 0.9475826972010178
# image #6
# IOU: 0.8130165338516235
# Dice: 0.8968660968660969
# image #7
# IOU: 0.699999988079071
# Dice: 0.8235294117647058
# image #8
# IOU: 0.5714285969734192
# Dice: 0.7272727272727273
# image #9
# IOU: 0.5853403210639954
# Dice: 0.7384412153236459
# image #10
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-8776ad1f276a> in <module>
#       8     batch_y = Y_valid[i:i + 1]
#       9
# ---> 10     pred = (model.predict(batch_X)[0, 0] > 0.5).astype(np.float64)
#      11     pred_cup.append(pred)
#      12     corr = th_to_tf_encoding(batch_y)[0, ..., 0]
#
# TypeError: list indices must be integers or slices, not tuple

# %% [markdown]
# Acquiring scores for the validation set:

# %%
print(np.mean(pred_iou))
print(np.mean(pred_dice))
# Out:
# 0.7583395
# 0.8574344532429837

# %% [markdown]
# ### Training and Test disc

# %%
X_valid, Z_valid = next(data_generator(red_channel_test, disc_test, disc_locations_test, train_or_test='test', batch_size=100, stationary=True))

# %%
history = model.fit_generator(data_generator(red_channel_train, disc_train, disc_locations, train_or_test='train', batch_size=1), 
                              steps_per_epoch=99,
                              max_queue_size=1,                    
                              validation_data=(X_valid, Z_valid),                              
                              epochs=500, verbose=1,                              
                              callbacks=[CSVLogger(os.path.join(folder(weights_folder), 'training_log_disc_red.csv')),
                                         ModelCheckpoint(os.path.join(folder(weights_folder),
                                               'last_checkpoint_disc_red.hdf5'),
                                               monitor='val_loss', mode='min', save_best_only=True, 
                                               save_weights_only=False, verbose=0)])
# Out:
# Epoch 1/500
# 99/99 [==============================] - 42s 428ms/step - loss: 0.1417 - mean_IOU_gpu: 0.7456 - dice_metric: 0.8462 - val_loss: 0.1008 - val_mean_IOU_gpu: 0.7956 - val_dice_metric: 0.8823
# Epoch 2/500
# 99/99 [==============================] - 40s 406ms/step - loss: 0.1005 - mean_IOU_gpu: 0.7845 - dice_metric: 0.8768 - val_loss: 0.0992 - val_mean_IOU_gpu: 0.7990 - val_dice_metric: 0.8846
# Epoch 3/500
# 99/99 [==============================] - 47s 474ms/step - loss: 0.0887 - mean_IOU_gpu: 0.8062 - dice_metric: 0.8903 - val_loss: 0.0897 - val_mean_IOU_gpu: 0.8122 - val_dice_metric: 0.8936
# Epoch 4/500
# 99/99 [==============================] - 52s 527ms/step - loss: 0.0846 - mean_IOU_gpu: 0.8127 - dice_metric: 0.8947 - val_loss: 0.0927 - val_mean_IOU_gpu: 0.8084 - val_dice_metric: 0.8910
# Epoch 5/500
# 99/99 [==============================] - 47s 470ms/step - loss: 0.0758 - mean_IOU_gpu: 0.8294 - dice_metric: 0.9049 - val_loss: 0.0962 - val_mean_IOU_gpu: 0.8037 - val_dice_metric: 0.8879
# Epoch 6/500
# 99/99 [==============================] - 50s 500ms/step - loss: 0.0871 - mean_IOU_gpu: 0.8111 - dice_metric: 0.8940 - val_loss: 0.0992 - val_mean_IOU_gpu: 0.8001 - val_dice_metric: 0.8855
# Epoch 7/500
# 99/99 [==============================] - 50s 503ms/step - loss: 0.0770 - mean_IOU_gpu: 0.8276 - dice_metric: 0.9043 - val_loss: 0.1252 - val_mean_IOU_gpu: 0.7626 - val_dice_metric: 0.8612
# Epoch 8/500
# 99/99 [==============================] - 58s 585ms/step - loss: 0.0842 - mean_IOU_gpu: 0.8164 - dice_metric: 0.8971 - val_loss: 0.0852 - val_mean_IOU_gpu: 0.8181 - val_dice_metric: 0.8975
# Epoch 9/500
# 99/99 [==============================] - 55s 557ms/step - loss: 0.0809 - mean_IOU_gpu: 0.8196 - dice_metric: 0.8993 - val_loss: 0.0955 - val_mean_IOU_gpu: 0.8034 - val_dice_metric: 0.8879
# Epoch 10/500
# 99/99 [==============================] - 52s 525ms/step - loss: 0.0823 - mean_IOU_gpu: 0.8203 - dice_metric: 0.8996 - val_loss: 0.0873 - val_mean_IOU_gpu: 0.8150 - val_dice_metric: 0.8954
# Epoch 11/500
# 99/99 [==============================] - 51s 510ms/step - loss: 0.0833 - mean_IOU_gpu: 0.8167 - dice_metric: 0.8975 - val_loss: 0.0862 - val_mean_IOU_gpu: 0.8165 - val_dice_metric: 0.8964
# Epoch 12/500
# 99/99 [==============================] - 51s 519ms/step - loss: 0.0823 - mean_IOU_gpu: 0.8179 - dice_metric: 0.8984 - val_loss: 0.0857 - val_mean_IOU_gpu: 0.8163 - val_dice_metric: 0.8964
# Epoch 13/500
# 99/99 [==============================] - 49s 492ms/step - loss: 0.0776 - mean_IOU_gpu: 0.8261 - dice_metric: 0.9033 - val_loss: 0.0869 - val_mean_IOU_gpu: 0.8154 - val_dice_metric: 0.8957
# Epoch 14/500
# 99/99 [==============================] - 47s 476ms/step - loss: 0.0776 - mean_IOU_gpu: 0.8258 - dice_metric: 0.9032 - val_loss: 0.0844 - val_mean_IOU_gpu: 0.8189 - val_dice_metric: 0.8981
# Epoch 15/500
# 99/99 [==============================] - 49s 494ms/step - loss: 0.0739 - mean_IOU_gpu: 0.8325 - dice_metric: 0.9074 - val_loss: 0.0871 - val_mean_IOU_gpu: 0.8119 - val_dice_metric: 0.8939
# Epoch 16/500
# 99/99 [==============================] - 55s 559ms/step - loss: 0.0767 - mean_IOU_gpu: 0.8267 - dice_metric: 0.9036 - val_loss: 0.0866 - val_mean_IOU_gpu: 0.8158 - val_dice_metric: 0.8960
# Epoch 17/500
# 99/99 [==============================] - 45s 455ms/step - loss: 0.0757 - mean_IOU_gpu: 0.8305 - dice_metric: 0.9060 - val_loss: 0.0849 - val_mean_IOU_gpu: 0.8183 - val_dice_metric: 0.8974
# Epoch 18/500
# 99/99 [==============================] - 43s 430ms/step - loss: 0.0709 - mean_IOU_gpu: 0.8375 - dice_metric: 0.9105 - val_loss: 0.0836 - val_mean_IOU_gpu: 0.8186 - val_dice_metric: 0.8980
# Epoch 19/500
# 99/99 [==============================] - 45s 459ms/step - loss: 0.0740 - mean_IOU_gpu: 0.8314 - dice_metric: 0.9068 - val_loss: 0.0823 - val_mean_IOU_gpu: 0.8209 - val_dice_metric: 0.8994
# Epoch 20/500
# 99/99 [==============================] - 44s 443ms/step - loss: 0.0740 - mean_IOU_gpu: 0.8342 - dice_metric: 0.9082 - val_loss: 0.0831 - val_mean_IOU_gpu: 0.8196 - val_dice_metric: 0.8985
# Epoch 21/500
# 99/99 [==============================] - 44s 448ms/step - loss: 0.0750 - mean_IOU_gpu: 0.8314 - dice_metric: 0.9066 - val_loss: 0.0862 - val_mean_IOU_gpu: 0.8155 - val_dice_metric: 0.8959
# Epoch 22/500
# 99/99 [==============================] - 42s 420ms/step - loss: 0.0744 - mean_IOU_gpu: 0.8310 - dice_metric: 0.9065 - val_loss: 0.0899 - val_mean_IOU_gpu: 0.8081 - val_dice_metric: 0.8917
# Epoch 23/500
# 99/99 [==============================] - 44s 440ms/step - loss: 0.0723 - mean_IOU_gpu: 0.8367 - dice_metric: 0.9098 - val_loss: 0.0837 - val_mean_IOU_gpu: 0.8199 - val_dice_metric: 0.8985
# Epoch 24/500
# 99/99 [==============================] - 43s 430ms/step - loss: 0.0707 - mean_IOU_gpu: 0.8384 - dice_metric: 0.9112 - val_loss: 0.0873 - val_mean_IOU_gpu: 0.8123 - val_dice_metric: 0.8941
# Epoch 25/500
# 99/99 [==============================] - 44s 441ms/step - loss: 0.0762 - mean_IOU_gpu: 0.8290 - dice_metric: 0.9054 - val_loss: 0.0878 - val_mean_IOU_gpu: 0.8132 - val_dice_metric: 0.8944
# Epoch 26/500
# 99/99 [==============================] - 41s 418ms/step - loss: 0.0808 - mean_IOU_gpu: 0.8222 - dice_metric: 0.9006 - val_loss: 0.0878 - val_mean_IOU_gpu: 0.8116 - val_dice_metric: 0.8937
# Epoch 27/500
# 99/99 [==============================] - 44s 445ms/step - loss: 0.0699 - mean_IOU_gpu: 0.8370 - dice_metric: 0.9102 - val_loss: 0.0830 - val_mean_IOU_gpu: 0.8207 - val_dice_metric: 0.8993
# Epoch 28/500
# 99/99 [==============================] - 41s 413ms/step - loss: 0.0724 - mean_IOU_gpu: 0.8355 - dice_metric: 0.9093 - val_loss: 0.0875 - val_mean_IOU_gpu: 0.8114 - val_dice_metric: 0.8935
# Epoch 29/500
# 99/99 [==============================] - 41s 411ms/step - loss: 0.0707 - mean_IOU_gpu: 0.8397 - dice_metric: 0.9117 - val_loss: 0.0834 - val_mean_IOU_gpu: 0.8195 - val_dice_metric: 0.8985
# Epoch 30/500
# 99/99 [==============================] - 43s 433ms/step - loss: 0.0737 - mean_IOU_gpu: 0.8343 - dice_metric: 0.9084 - val_loss: 0.0892 - val_mean_IOU_gpu: 0.8083 - val_dice_metric: 0.8916
# Epoch 31/500
# 99/99 [==============================] - 43s 429ms/step - loss: 0.0716 - mean_IOU_gpu: 0.8369 - dice_metric: 0.9100 - val_loss: 0.0853 - val_mean_IOU_gpu: 0.8174 - val_dice_metric: 0.8971
# Epoch 32/500
# 99/99 [==============================] - 47s 477ms/step - loss: 0.0711 - mean_IOU_gpu: 0.8376 - dice_metric: 0.9105 - val_loss: 0.0901 - val_mean_IOU_gpu: 0.8085 - val_dice_metric: 0.8917
# Epoch 33/500
# 99/99 [==============================] - 51s 520ms/step - loss: 0.0689 - mean_IOU_gpu: 0.8416 - dice_metric: 0.9128 - val_loss: 0.0862 - val_mean_IOU_gpu: 0.8166 - val_dice_metric: 0.8964
# Epoch 34/500
# 99/99 [==============================] - 46s 465ms/step - loss: 0.0714 - mean_IOU_gpu: 0.8397 - dice_metric: 0.9113 - val_loss: 0.0880 - val_mean_IOU_gpu: 0.8139 - val_dice_metric: 0.8947
# Epoch 35/500
# 99/99 [==============================] - 44s 445ms/step - loss: 0.0711 - mean_IOU_gpu: 0.8374 - dice_metric: 0.9104 - val_loss: 0.0860 - val_mean_IOU_gpu: 0.8153 - val_dice_metric: 0.8959
# Epoch 36/500
# 99/99 [==============================] - 44s 443ms/step - loss: 0.0653 - mean_IOU_gpu: 0.8518 - dice_metric: 0.9189 - val_loss: 0.0871 - val_mean_IOU_gpu: 0.8125 - val_dice_metric: 0.8943
# Epoch 37/500
# 99/99 [==============================] - 44s 441ms/step - loss: 0.0698 - mean_IOU_gpu: 0.8394 - dice_metric: 0.9116 - val_loss: 0.0953 - val_mean_IOU_gpu: 0.7984 - val_dice_metric: 0.8854
# Epoch 38/500
# 99/99 [==============================] - 42s 428ms/step - loss: 0.0769 - mean_IOU_gpu: 0.8288 - dice_metric: 0.9048 - val_loss: 0.0892 - val_mean_IOU_gpu: 0.8101 - val_dice_metric: 0.8924
# Epoch 39/500
# 99/99 [==============================] - 43s 431ms/step - loss: 0.0679 - mean_IOU_gpu: 0.8446 - dice_metric: 0.9146 - val_loss: 0.0864 - val_mean_IOU_gpu: 0.8137 - val_dice_metric: 0.8950
# Epoch 40/500
# 99/99 [==============================] - 43s 432ms/step - loss: 0.0736 - mean_IOU_gpu: 0.8343 - dice_metric: 0.9083 - val_loss: 0.0832 - val_mean_IOU_gpu: 0.8201 - val_dice_metric: 0.8989
# Epoch 41/500
# 99/99 [==============================] - 43s 438ms/step - loss: 0.0744 - mean_IOU_gpu: 0.8318 - dice_metric: 0.9069 - val_loss: 0.0838 - val_mean_IOU_gpu: 0.8182 - val_dice_metric: 0.8976
# Epoch 42/500
# 99/99 [==============================] - 44s 441ms/step - loss: 0.0735 - mean_IOU_gpu: 0.8349 - dice_metric: 0.9087 - val_loss: 0.0846 - val_mean_IOU_gpu: 0.8174 - val_dice_metric: 0.8971
# Epoch 43/500
# 99/99 [==============================] - 45s 450ms/step - loss: 0.0674 - mean_IOU_gpu: 0.8464 - dice_metric: 0.9157 - val_loss: 0.0839 - val_mean_IOU_gpu: 0.8182 - val_dice_metric: 0.8978
# Epoch 44/500
# 99/99 [==============================] - 43s 439ms/step - loss: 0.0654 - mean_IOU_gpu: 0.8506 - dice_metric: 0.9182 - val_loss: 0.0836 - val_mean_IOU_gpu: 0.8188 - val_dice_metric: 0.8980
# Epoch 45/500
# 99/99 [==============================] - 43s 433ms/step - loss: 0.0651 - mean_IOU_gpu: 0.8514 - dice_metric: 0.9186 - val_loss: 0.0894 - val_mean_IOU_gpu: 0.8090 - val_dice_metric: 0.8920
# Epoch 46/500
# 99/99 [==============================] - 42s 420ms/step - loss: 0.0681 - mean_IOU_gpu: 0.8432 - dice_metric: 0.9139 - val_loss: 0.0862 - val_mean_IOU_gpu: 0.8155 - val_dice_metric: 0.8957
# Epoch 47/500
# 99/99 [==============================] - 42s 423ms/step - loss: 0.0666 - mean_IOU_gpu: 0.8469 - dice_metric: 0.9162 - val_loss: 0.0865 - val_mean_IOU_gpu: 0.8139 - val_dice_metric: 0.8949
# Epoch 48/500
# 99/99 [==============================] - 42s 422ms/step - loss: 0.0681 - mean_IOU_gpu: 0.8436 - dice_metric: 0.9140 - val_loss: 0.0844 - val_mean_IOU_gpu: 0.8182 - val_dice_metric: 0.8975
# Epoch 49/500
# 99/99 [==============================] - 42s 425ms/step - loss: 0.0684 - mean_IOU_gpu: 0.8429 - dice_metric: 0.9135 - val_loss: 0.0894 - val_mean_IOU_gpu: 0.8113 - val_dice_metric: 0.8930
# Epoch 50/500
# 99/99 [==============================] - 42s 424ms/step - loss: 0.0709 - mean_IOU_gpu: 0.8389 - dice_metric: 0.9112 - val_loss: 0.0869 - val_mean_IOU_gpu: 0.8128 - val_dice_metric: 0.8943
# Epoch 51/500
# 99/99 [==============================] - 44s 448ms/step - loss: 0.0661 - mean_IOU_gpu: 0.8502 - dice_metric: 0.9177 - val_loss: 0.0829 - val_mean_IOU_gpu: 0.8219 - val_dice_metric: 0.8998
# Epoch 52/500
# 99/99 [==============================] - 43s 438ms/step - loss: 0.0676 - mean_IOU_gpu: 0.8446 - dice_metric: 0.9147 - val_loss: 0.0855 - val_mean_IOU_gpu: 0.8156 - val_dice_metric: 0.8962
# Epoch 53/500
# 99/99 [==============================] - 41s 415ms/step - loss: 0.0665 - mean_IOU_gpu: 0.8461 - dice_metric: 0.9158 - val_loss: 0.0863 - val_mean_IOU_gpu: 0.8156 - val_dice_metric: 0.8959
# Epoch 54/500
# 99/99 [==============================] - 42s 429ms/step - loss: 0.0655 - mean_IOU_gpu: 0.8484 - dice_metric: 0.9169 - val_loss: 0.0864 - val_mean_IOU_gpu: 0.8156 - val_dice_metric: 0.8958
# Epoch 55/500
# 99/99 [==============================] - 45s 452ms/step - loss: 0.0747 - mean_IOU_gpu: 0.8331 - dice_metric: 0.9076 - val_loss: 0.0783 - val_mean_IOU_gpu: 0.8274 - val_dice_metric: 0.9037
# Epoch 56/500
# 99/99 [==============================] - 50s 505ms/step - loss: 0.0681 - mean_IOU_gpu: 0.8440 - dice_metric: 0.9144 - val_loss: 0.0812 - val_mean_IOU_gpu: 0.8235 - val_dice_metric: 0.9010
# Epoch 57/500
# 99/99 [==============================] - 53s 533ms/step - loss: 0.0668 - mean_IOU_gpu: 0.8474 - dice_metric: 0.9165 - val_loss: 0.0835 - val_mean_IOU_gpu: 0.8192 - val_dice_metric: 0.8984
# Epoch 58/500
# 99/99 [==============================] - 55s 553ms/step - loss: 0.0639 - mean_IOU_gpu: 0.8525 - dice_metric: 0.9194 - val_loss: 0.0846 - val_mean_IOU_gpu: 0.8182 - val_dice_metric: 0.8976
# Epoch 59/500
# 99/99 [==============================] - 50s 507ms/step - loss: 0.0586 - mean_IOU_gpu: 0.8611 - dice_metric: 0.9247 - val_loss: 0.0884 - val_mean_IOU_gpu: 0.8104 - val_dice_metric: 0.8930
# Epoch 60/500
# 99/99 [==============================] - 54s 547ms/step - loss: 0.0670 - mean_IOU_gpu: 0.8459 - dice_metric: 0.9155 - val_loss: 0.0898 - val_mean_IOU_gpu: 0.8095 - val_dice_metric: 0.8922
# Epoch 61/500
# 99/99 [==============================] - 49s 490ms/step - loss: 0.0689 - mean_IOU_gpu: 0.8432 - dice_metric: 0.9138 - val_loss: 0.0885 - val_mean_IOU_gpu: 0.8120 - val_dice_metric: 0.8937
# Epoch 62/500
# 99/99 [==============================] - 48s 481ms/step - loss: 0.0690 - mean_IOU_gpu: 0.8434 - dice_metric: 0.9139 - val_loss: 0.0858 - val_mean_IOU_gpu: 0.8166 - val_dice_metric: 0.8967
# Epoch 63/500
# 99/99 [==============================] - 47s 474ms/step - loss: 0.0676 - mean_IOU_gpu: 0.8457 - dice_metric: 0.9154 - val_loss: 0.0842 - val_mean_IOU_gpu: 0.8189 - val_dice_metric: 0.8980
# Epoch 64/500
# 99/99 [==============================] - 48s 480ms/step - loss: 0.0621 - mean_IOU_gpu: 0.8531 - dice_metric: 0.9201 - val_loss: 0.0857 - val_mean_IOU_gpu: 0.8166 - val_dice_metric: 0.8966
# Epoch 65/500
# 99/99 [==============================] - 48s 485ms/step - loss: 0.0678 - mean_IOU_gpu: 0.8453 - dice_metric: 0.9152 - val_loss: 0.0835 - val_mean_IOU_gpu: 0.8191 - val_dice_metric: 0.8983
# Epoch 66/500
# 99/99 [==============================] - 48s 487ms/step - loss: 0.0634 - mean_IOU_gpu: 0.8533 - dice_metric: 0.9199 - val_loss: 0.0826 - val_mean_IOU_gpu: 0.8222 - val_dice_metric: 0.9001
# Epoch 67/500
# 99/99 [==============================] - 48s 487ms/step - loss: 0.0672 - mean_IOU_gpu: 0.8462 - dice_metric: 0.9155 - val_loss: 0.0896 - val_mean_IOU_gpu: 0.8088 - val_dice_metric: 0.8919
# Epoch 68/500
# 99/99 [==============================] - 51s 511ms/step - loss: 0.0639 - mean_IOU_gpu: 0.8531 - dice_metric: 0.9197 - val_loss: 0.0834 - val_mean_IOU_gpu: 0.8209 - val_dice_metric: 0.8992
# Epoch 69/500
# 99/99 [==============================] - 50s 505ms/step - loss: 0.0602 - mean_IOU_gpu: 0.8592 - dice_metric: 0.9235 - val_loss: 0.0863 - val_mean_IOU_gpu: 0.8160 - val_dice_metric: 0.8962
# Epoch 70/500
# 99/99 [==============================] - 46s 465ms/step - loss: 0.0671 - mean_IOU_gpu: 0.8475 - dice_metric: 0.9161 - val_loss: 0.0839 - val_mean_IOU_gpu: 0.8202 - val_dice_metric: 0.8988
# Epoch 71/500
# 49/99 [=============>................] - ETA: 27s - loss: 0.0643 - mean_IOU_gpu: 0.8511 - dice_metric: 0.9188
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-36818afdfa8c> in <module>
#       8                                                'last_checkpoint_disc_red.hdf5'),
#       9                                                monitor='val_loss', mode='min', save_best_only=True,
# ---> 10                                                save_weights_only=False, verbose=0)])
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1730             use_multiprocessing=use_multiprocessing,
#    1731             shuffle=shuffle,
# -> 1732             initial_epoch=initial_epoch)
#    1733
#    1734     @interfaces.legacy_generator_methods_support
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     218                                             sample_weight=sample_weight,
#     219                                             class_weight=class_weight,
# --> 220                                             reset_metrics=False)
#     221
#     222                 outs = to_list(outs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics)
#    1512             ins = x + y + sample_weights
#    1513         self._make_train_function()
# -> 1514         outputs = self.train_function(ins)
#    1515
#    1516         if reset_metrics:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in __call__(self, inputs)
#    3290
#    3291     fetched = self._callable_fn(*array_vals,
# -> 3292                                 run_metadata=self.run_metadata)
#    3293     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3294     output_structure = nest.pack_sequence_as(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
pred_iou, pred_dice = [], []
pred_disc = []

for i, img_no in enumerate(test_idx):
    print('image #{}'.format(img_no))
    img = red_channel_test[img_no]
    batch_X = X_valid[i:i + 1]
    batch_z = Z_valid[i:i + 1]
    
    pred = (model.predict(batch_X)[0, 0] > 0.5).astype(np.float64)
    pred_disc.append(pred)
    corr = th_to_tf_encoding(batch_z)[0, ..., 0]
        
    fig = plt.figure(figsize=(9, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.imshow(pred, cmap=plt.cm.Greys_r)
    ax.set_title('Predicted')
    ax = fig.add_subplot(1, 3, 2)
    ax.imshow(corr, cmap=plt.cm.Greys_r)
    ax.set_title('Correct')
    ax = fig.add_subplot(1, 3, 3)
    ax.imshow(th_to_tf_encoding(batch_X)[0])
    ax.set_title('Image')
    plt.show()
    
    cur_iou = K.eval(mean_IOU_gpu(pred[None, None, ...], corr[None, None, ...]))
    cur_dice = K.eval(dice(pred[None, None, ...], corr[None, None, ...]))
    print('IOU: {}\nDice: {}'.format(cur_iou, cur_dice))
    pred_iou.append(cur_iou)
    pred_dice.append(cur_dice)

# %%
print(np.mean(pred_iou))
print(np.mean(pred_dice))

# %% [markdown]
# ### Cálculo do CDR

# %%
def ellipseFitting(img):
    contours, hierarchy = cv2.findContours(img.copy(),cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)
    ellipse = np.zeros(img.shape)
    diametro = []
    for ind, cont in enumerate(contours):
        (x,y),(MA,ma),angle = cv2.fitEllipse(cont)
        diametro.append((MA, ma))
        #feed the parsed parameters into cv2.ellipse
        cv2.ellipse(ellipse,(int(x),int(y)),(int(MA/2), int(ma/2)),angle,0,360,(255,255,255),0)
    return ellipse, diametro

# %%
cdrs = []
for i, img_no in enumerate(test_idx):
    cup = pred_cup[i]
    disc = pred_disc[i]
        
    c = cv2.Canny(cup.astype(np.uint8), 1,1)
    d = cv2.Canny(disc.astype(np.uint8), 1,1)
    
    el_c, diam_c = ellipseFitting(c)
    el_d, diam_d = ellipseFitting(d)
        
    if len(diam_d) > 0 and len(diam_c) > 0:
        cdr = diam_c[0][1]/diam_d[0][1]
        cdrs.append(cdr)
        print('image #{} - cdr = {}'.format(img_no, cdr))
